# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import numpy as np
import matplotlib.pyplot as plt

# %%
accuracies = []
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-04 With 2 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-04 With 3 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-04 With 4 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-04 With 5 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-04 With 6 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-04 With 7 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-04 With 8 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-04 With 9 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-04 With 10 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-04 With 11 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-04 With 12 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-04 With 13 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-04 With 14 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-04 With 15 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-04 With 16 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-04 With 17 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-02 With 18 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-04 With 19 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-04 With 20 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
# with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-04 With 21 Attributes.json", "r") as f:
#   rep = json.load(f)
# accuracies.append(rep["accuracy_test"])
# with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-05 With 22 Attributes.json", "r") as f:
#   rep = json.load(f)
# accuracies.append(rep["accuracy_test"])
# with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-05 With 23 Attributes.json", "r") as f:
#   rep = json.load(f)
# accuracies.append(rep["accuracy_test"])
# with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-05 With 24 Attributes.json", "r") as f:
#   rep = json.load(f)
# accuracies.append(rep["accuracy_test"])
# with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-05 With 25 Attributes.json", "r") as f:
#   rep = json.load(f)
# accuracies.append(rep["accuracy_test"])
# with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-05 With 26 Attributes.json", "r") as f:
#   rep = json.load(f)
# accuracies.append(rep["accuracy_test"])
# with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-05 With 27 Attributes.json", "r") as f:
#   rep = json.load(f)
# accuracies.append(rep["accuracy_test"])
# with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-05 With 28 Attributes.json", "r") as f:
#   rep = json.load(f)
# accuracies.append(rep["accuracy_test"])
# with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-05 With 29 Attributes.json", "r") as f:
#   rep = json.load(f)
# accuracies.append(rep["accuracy_test"])


max_acc = max(accuracies)
min_acc = min(accuracies)
len_acc = len(accuracies)

xc = range(2,len_acc+2)
plt.figure()
plt.plot(xc, accuracies)
plt.ylabel('Acurácia de teste')
plt.xlabel('Número de atributos')
plt.title('Acurácia de teste por número de atributos')

y=np.arange(0.9,0.99,0.005)
z=np.arange(min_acc,max_acc,0.005)

plt.xticks(range(len(accuracies)+2))
plt.yticks(y)
plt.ylim(min_acc-0.0025, max_acc+0.0025)
for i in y:
  plt.axhline(i, color="black", linestyle=":")
for i in range(0,len_acc+2,2):
  plt.axvline(i, color="black", linestyle=":")
  

plt.savefig("/content/drive/MyDrive/IC-Skynet/NNreports/knee_curve_%s"%current_date_and_time_string





print()
# Out:
#   File "<ipython-input-1-5cd801bdc957>", line 118
#     print()
#         ^
# SyntaxError: invalid syntax
