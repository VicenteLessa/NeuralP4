# %%
from google.colab import drive
drive.mount('/content/drive')
from datetime import datetime
from keras.callbacks import History
history = History()
from jinja2 import Environment, FileSystemLoader
import json
import numpy as np
import os
import pandas as pd
import sys
import tensorflow as tf
import matplotlib.pyplot as plt
import math
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Parameters to specify

# %%
#example: Q16.8 -> precision = 8, wordsize = 24, double = 48
#specify:
PRECISION = 16
INTEGER = 16
WORDSIZE = INTEGER + PRECISION
D_WORDSIZE = 2*WORDSIZE
SLACK = 8-(WORDSIZE%8)

df_number = 1


nn_topo_title = "/content/drive/MyDrive/network-traffic-classification-main/nn-reports/nn_model_parameters.json"
load_model_title = '/content/drive/MyDrive/network-traffic-classification-main/tf-models/model_with_2_attributes_2_hidden_nodes.csv'
path_test = f'/content/drive/MyDrive/network-traffic-classification-main/csv-files/df_test_4000_samples_2_classes.csv'

# %%
n_bits = WORDSIZE
#for jinja template
wordsize = WORDSIZE
precision = PRECISION
slack = SLACK
print(slack)
# Out:
# 8

# %% [markdown]
# ### Load NN parameters and model

# %%
#Load file with NN topology
with open(nn_topo_title, "r") as f:
  rep = json.load(f)

#Get NN topology and information to load correct dataframes
attributes_array = rep["attributes"]
number_of_attributes = rep["number_of_attributes"]
hidden_layer_nodes = rep["hidden_layer_nodes"]
output_layer_nodes = rep["output_layer_nodes"]
accuracy_test = rep["accuracy_test"]
batch_size = rep["batch_size"]
epochs = rep["epochs"]
number_of_samples = 4000
df_number = 1

#load dataframes and adequate them for file generation
#path_train = '/content/drive/MyDrive/network-traffic-classification-main/csv-files/df_train_with%d'%number_of_samples + 'samples_per_class%d'%df_number + '.csv'
#df_train_raw = pd.read_csv(path_train)
df_test_raw = pd.read_csv(path_test)
#display(df_test_raw)
df_test = df_test_raw[attributes_array]
display(df_test)
target_test = df_test_raw['target']


#load model to get weights
print(load_model_title)
model = tf.keras.models.load_model(load_model_title)

norm_layer_weights = model.layers[0].get_weights()[0] #weight
norm_layer_biases  = model.layers[0].get_weights()[1] #bias
hidden_layer_weights = model.layers[1].get_weights()[0] #weight
hidden_layer_biases  = model.layers[1].get_weights()[1] #bias
out_layer_weights = model.layers[2].get_weights()[0] #weight
out_layer_biases  = model.layers[2].get_weights()[1] #bias
print('\nInput -> Normalization Layer bias:\n',norm_layer_biases)
print('\nInput -> Normalization Layer weights:\n',norm_layer_weights)
print('\nNormalization -> Hidden Layer bias:\n',hidden_layer_biases)
print('\nNormalization -> Hidden Layer weights:\n',hidden_layer_weights)
print('\nHidden -> Output Layer bias:\n',out_layer_biases)
# print('\nHidden -> Output Layer weights:\n',out_layer_weights,'\n')
# Out:
#         82    83
# 0      199     6
# 1     1143  1029
# 2      536   324
# 3       88     6
# 4      399   277
# ...    ...   ...
# 3995    92     6
# 3996    96     6
# 3997   536   271
# 3998    96     6
# 3999    92     6
#
# [4000 rows x 2 columns]
# /content/drive/MyDrive/network-traffic-classification-main/tf-models/model_with_2_attributes_2_hidden_nodes.csv
#
# Input -> Normalization Layer bias:
#  [198789.9    63950.344]
#
# Input -> Normalization Layer weights:
#  [387.3301  204.38979]
#
# Normalization -> Hidden Layer bias:
#  [1.1116455 1.4133354]
#
# Normalization -> Hidden Layer weights:
#  [[0.04945677 0.16049963]
#  [1.3844367  1.6790601 ]]
#
# Hidden -> Output Layer bias:
#  [-2.382677  2.382676]

# %%
def num_to_c2(num, wordsize):
  if(num < 0):
    return 2**wordsize + num
  return num

# %% [markdown]
# ### file generator for P4 csv input

# %%
df_test.to_csv(f"/content/drive/MyDrive/network-traffic-classification-main/code/csv_files_input/df_test_{df_number}_with_{number_of_attributes}_attributes.csv", index=False)
target_test.to_csv(f"/content/drive/MyDrive/network-traffic-classification-main/csv-files/test_target_{df_number}_with_{number_of_attributes}_attributes.csv", index=False)

# %% [markdown]
# ###  file generator for TF predictions
# to be compared to P4_prediction in the analiser

# %%
tf_predictions_probabilities = model.predict(df_test)
tf_loss, tf_acc =  model.evaluate(df_test,  target_test, verbose=2, batch_size=batch_size)

tf_predictions = []

for i,x in enumerate(tf_predictions_probabilities):
  #print("i:",i,"x_max:",x.max(),"x:",x)
  j_max = x.argmax()
  tf_predictions.append(j_max)

conf_m = tf.math.confusion_matrix(target_test,tf_predictions)
print(conf_m)

df_tf = pd.DataFrame(tf_predictions_probabilities)
df_tf.insert(loc = 0, column = "tf_predictions", value = tf_predictions)
#print(df_tf)

title_for_analiser = "/content/drive/MyDrive/network-traffic-classification-main/csv-files/tf_outputs_classifications.csv"
df_tf.to_csv(title_for_analiser, index=False)
# Out:
# 125/125 [==============================] - 0s 2ms/step
# 400/400 - 1s - loss: 0.0350 - accuracy: 0.9905 - 927ms/epoch - 2ms/step
# tf.Tensor(
# [[1962   38]
#  [   0 2000]], shape=(2, 2), dtype=int32)

# %% [markdown]
# ### Topology file generator for sx

# %%
weights = norm_layer_weights
biases = norm_layer_biases


#number of norm_layer_nodes = number_of_attributes
for i in range(number_of_attributes):
  sx_id = 1+i

  sx_entries = {
    "target": "bmv2",
    "p4info": "build/ANN.p4.p4info.txt",
    "bmv2_json": "build/ANN.json",
    "table_entries": [
      {
        "table": "MyIngress.ann_forward",
        "match": {
          "standard_metadata.ingress_port": 1
        },
        "action_name": "MyIngress.mcast",
        "action_params": {
          "mgroup": sx_id
        }
      },
      {
        "table": "MyIngress.tab_neuron_id",
        "default_action": True,
        "action_name": "MyIngress.set_neuron_id",
        "action_params": {
          "neuron_id": sx_id
        }
      },
      {
        "table": "MyIngress.tab_n_expected_stimuli",
        "default_action": True,
        "action_name": "MyIngress.set_n_expected_stimuli",
        "action_params": {
          "n_expected_stimuli": 1
        }
      },
      {
        "table": "MyIngress.tab_expected_stimuli",
        "default_action": True,
        "action_name": "MyIngress.set_expected_stimuli",
        "action_params": {
          "expected_stimuli": 1
        }
      },
      {
        "table": "MyIngress.tab_agg_func",
        "default_action": True,
        "action_name": "MyIngress.set_agg_func",
        "action_params": {
          "agg_func": 5
        }
      },
      {
        "table": "MyIngress.tab_activation_func",
        "default_action": True,
        "action_name": "MyIngress.set_activation_func",
        "action_params": {
          "activation_func": 2
        }
      }
    ],
    "multicast_group_entries":[
      {
        "multicast_group_id" : sx_id,
        "replicas": []
      }
    ]
  }
  for h in range(hidden_layer_nodes):
    sx_entries["multicast_group_entries"][0]["replicas"].append(
      {
        "egress_port" :51+h,
        "instance": 1
      }
    )

  #print(sx_entries["table_entries"])
  attr_name = attributes_array[i]
  # for each unique value for this attribute in the dataframe
  if (i == 0):
    for raw_value in sorted(df_test[attr_name].unique()):
      raw_value = int(raw_value)
      normalized_value = (raw_value - weights[i]) / math.sqrt(biases[i]) # normalize according to the formula
      new_normalized_value = (raw_value + (-weights[i])) * (math.sqrt(biases[i])) ** -1
      fp_normalized_value = int(normalized_value * (2**PRECISION)) # transform into fixed point representation
      c2_normalized_value = num_to_c2(fp_normalized_value, n_bits) # transform into 2's complement representation

      print(f"j:{raw_value} ,weights[i]:{weights[i]}, math.sqrt(biases[i]:{math.sqrt(biases[i])}")
      print(f"normalized_value:{normalized_value}")
      print(f"new_normalized_value:{new_normalized_value}")
      print(f"fp_normalized_value:{fp_normalized_value}")
      print(f"c2_normalized_value:{c2_normalized_value}")

      sx_entries["table_entries"].append(
        {
          "table": "MyIngress.tab_normalization",
          "match": {
            "hdr.ann.data": raw_value
          },
          "action_name": "MyIngress.set_normalization",
          "action_params": {
            "normalized_data": c2_normalized_value
          }
        }
      )


  #print(sx_entries["table_entries"])

  sx_file_title = "/content/drive/MyDrive/network-traffic-classification-main/code/topology/s%d"%sx_id + "-runtime.json"
  with open(sx_file_title, "w") as f:
    json.dump(sx_entries, f, indent = 2)




# print(json.dumps(sx_entries, indent = 2))
# Out:
# j:0 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.8687285475141361
# new_normalized_value:-0.8687285475141361
# fp_normalized_value:-56932
# c2_normalized_value:4294910364
# j:1 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.8664856840544412
# new_normalized_value:-0.8664856840544412
# fp_normalized_value:-56786
# c2_normalized_value:4294910510
# j:5 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.8575142302156611
# new_normalized_value:-0.8575142302156611
# fp_normalized_value:-56198
# c2_normalized_value:4294911098
# j:6 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.855271366755966
# new_normalized_value:-0.855271366755966
# fp_normalized_value:-56051
# c2_normalized_value:4294911245
# j:24 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.8148998244814559
# new_normalized_value:-0.8148998244814559
# fp_normalized_value:-53405
# c2_normalized_value:4294913891
# j:34 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7924711898845058
# new_normalized_value:-0.7924711898845058
# fp_normalized_value:-51935
# c2_normalized_value:4294915361
# j:37 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7857425995054208
# new_normalized_value:-0.7857425995054208
# fp_normalized_value:-51494
# c2_normalized_value:4294915802
# j:38 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7834997360457259
# new_normalized_value:-0.7834997360457259
# fp_normalized_value:-51347
# c2_normalized_value:4294915949
# j:39 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7812568725860308
# new_normalized_value:-0.7812568725860308
# fp_normalized_value:-51200
# c2_normalized_value:4294916096
# j:40 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7790140091263358
# new_normalized_value:-0.7790140091263358
# fp_normalized_value:-51053
# c2_normalized_value:4294916243
# j:41 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7767711456666407
# new_normalized_value:-0.7767711456666407
# fp_normalized_value:-50906
# c2_normalized_value:4294916390
# j:42 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7745282822069458
# new_normalized_value:-0.7745282822069458
# fp_normalized_value:-50759
# c2_normalized_value:4294916537
# j:44 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7700425552875557
# new_normalized_value:-0.7700425552875557
# fp_normalized_value:-50465
# c2_normalized_value:4294916831
# j:45 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7677996918278608
# new_normalized_value:-0.7677996918278608
# fp_normalized_value:-50318
# c2_normalized_value:4294916978
# j:48 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7610711014487758
# new_normalized_value:-0.7610711014487758
# fp_normalized_value:-49877
# c2_normalized_value:4294917419
# j:50 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7565853745293857
# new_normalized_value:-0.7565853745293857
# fp_normalized_value:-49583
# c2_normalized_value:4294917713
# j:51 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7543425110696907
# new_normalized_value:-0.7543425110696907
# fp_normalized_value:-49436
# c2_normalized_value:4294917860
# j:52 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7520996476099957
# new_normalized_value:-0.7520996476099957
# fp_normalized_value:-49289
# c2_normalized_value:4294918007
# j:53 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7498567841503007
# new_normalized_value:-0.7498567841503007
# fp_normalized_value:-49142
# c2_normalized_value:4294918154
# j:54 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7476139206906057
# new_normalized_value:-0.7476139206906057
# fp_normalized_value:-48995
# c2_normalized_value:4294918301
# j:55 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7453710572309107
# new_normalized_value:-0.7453710572309107
# fp_normalized_value:-48848
# c2_normalized_value:4294918448
# j:56 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7431281937712156
# new_normalized_value:-0.7431281937712156
# fp_normalized_value:-48701
# c2_normalized_value:4294918595
# j:57 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7408853303115207
# new_normalized_value:-0.7408853303115207
# fp_normalized_value:-48554
# c2_normalized_value:4294918742
# j:58 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7386424668518257
# new_normalized_value:-0.7386424668518257
# fp_normalized_value:-48407
# c2_normalized_value:4294918889
# j:59 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7363996033921306
# new_normalized_value:-0.7363996033921306
# fp_normalized_value:-48260
# c2_normalized_value:4294919036
# j:60 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7341567399324357
# new_normalized_value:-0.7341567399324357
# fp_normalized_value:-48113
# c2_normalized_value:4294919183
# j:61 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7319138764727406
# new_normalized_value:-0.7319138764727406
# fp_normalized_value:-47966
# c2_normalized_value:4294919330
# j:62 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7296710130130456
# new_normalized_value:-0.7296710130130456
# fp_normalized_value:-47819
# c2_normalized_value:4294919477
# j:63 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7274281495533507
# new_normalized_value:-0.7274281495533507
# fp_normalized_value:-47672
# c2_normalized_value:4294919624
# j:64 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7251852860936556
# new_normalized_value:-0.7251852860936556
# fp_normalized_value:-47525
# c2_normalized_value:4294919771
# j:65 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7229424226339606
# new_normalized_value:-0.7229424226339606
# fp_normalized_value:-47378
# c2_normalized_value:4294919918
# j:66 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7206995591742655
# new_normalized_value:-0.7206995591742655
# fp_normalized_value:-47231
# c2_normalized_value:4294920065
# j:67 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7184566957145706
# new_normalized_value:-0.7184566957145706
# fp_normalized_value:-47084
# c2_normalized_value:4294920212
# j:69 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7139709687951805
# new_normalized_value:-0.7139709687951805
# fp_normalized_value:-46790
# c2_normalized_value:4294920506
# j:71 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7094852418757905
# new_normalized_value:-0.7094852418757905
# fp_normalized_value:-46496
# c2_normalized_value:4294920800
# j:72 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7072423784160955
# new_normalized_value:-0.7072423784160955
# fp_normalized_value:-46349
# c2_normalized_value:4294920947
# j:73 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7049995149564006
# new_normalized_value:-0.7049995149564006
# fp_normalized_value:-46202
# c2_normalized_value:4294921094
# j:74 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7027566514967055
# new_normalized_value:-0.7027566514967055
# fp_normalized_value:-46055
# c2_normalized_value:4294921241
# j:75 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.7005137880370105
# new_normalized_value:-0.7005137880370105
# fp_normalized_value:-45908
# c2_normalized_value:4294921388
# j:76 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6982709245773155
# new_normalized_value:-0.6982709245773155
# fp_normalized_value:-45761
# c2_normalized_value:4294921535
# j:78 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6937851976579255
# new_normalized_value:-0.6937851976579255
# fp_normalized_value:-45467
# c2_normalized_value:4294921829
# j:79 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6915423341982305
# new_normalized_value:-0.6915423341982305
# fp_normalized_value:-45320
# c2_normalized_value:4294921976
# j:80 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6892994707385355
# new_normalized_value:-0.6892994707385355
# fp_normalized_value:-45173
# c2_normalized_value:4294922123
# j:81 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6870566072788404
# new_normalized_value:-0.6870566072788404
# fp_normalized_value:-45026
# c2_normalized_value:4294922270
# j:82 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6848137438191455
# new_normalized_value:-0.6848137438191455
# fp_normalized_value:-44879
# c2_normalized_value:4294922417
# j:83 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6825708803594505
# new_normalized_value:-0.6825708803594505
# fp_normalized_value:-44732
# c2_normalized_value:4294922564
# j:84 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6803280168997554
# new_normalized_value:-0.6803280168997554
# fp_normalized_value:-44585
# c2_normalized_value:4294922711
# j:85 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6780851534400605
# new_normalized_value:-0.6780851534400605
# fp_normalized_value:-44438
# c2_normalized_value:4294922858
# j:86 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6758422899803654
# new_normalized_value:-0.6758422899803654
# fp_normalized_value:-44292
# c2_normalized_value:4294923004
# j:87 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6735994265206704
# new_normalized_value:-0.6735994265206704
# fp_normalized_value:-44145
# c2_normalized_value:4294923151
# j:88 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6713565630609755
# new_normalized_value:-0.6713565630609755
# fp_normalized_value:-43998
# c2_normalized_value:4294923298
# j:89 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6691136996012804
# new_normalized_value:-0.6691136996012804
# fp_normalized_value:-43851
# c2_normalized_value:4294923445
# j:90 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6668708361415854
# new_normalized_value:-0.6668708361415854
# fp_normalized_value:-43704
# c2_normalized_value:4294923592
# j:91 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6646279726818903
# new_normalized_value:-0.6646279726818903
# fp_normalized_value:-43557
# c2_normalized_value:4294923739
# j:92 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6623851092221954
# new_normalized_value:-0.6623851092221954
# fp_normalized_value:-43410
# c2_normalized_value:4294923886
# j:93 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6601422457625004
# new_normalized_value:-0.6601422457625004
# fp_normalized_value:-43263
# c2_normalized_value:4294924033
# j:94 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6578993823028053
# new_normalized_value:-0.6578993823028053
# fp_normalized_value:-43116
# c2_normalized_value:4294924180
# j:95 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6556565188431104
# new_normalized_value:-0.6556565188431104
# fp_normalized_value:-42969
# c2_normalized_value:4294924327
# j:96 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6534136553834153
# new_normalized_value:-0.6534136553834153
# fp_normalized_value:-42822
# c2_normalized_value:4294924474
# j:97 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6511707919237203
# new_normalized_value:-0.6511707919237203
# fp_normalized_value:-42675
# c2_normalized_value:4294924621
# j:98 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6489279284640254
# new_normalized_value:-0.6489279284640254
# fp_normalized_value:-42528
# c2_normalized_value:4294924768
# j:99 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6466850650043303
# new_normalized_value:-0.6466850650043303
# fp_normalized_value:-42381
# c2_normalized_value:4294924915
# j:100 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6444422015446353
# new_normalized_value:-0.6444422015446353
# fp_normalized_value:-42234
# c2_normalized_value:4294925062
# j:101 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6421993380849403
# new_normalized_value:-0.6421993380849403
# fp_normalized_value:-42087
# c2_normalized_value:4294925209
# j:102 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6399564746252453
# new_normalized_value:-0.6399564746252453
# fp_normalized_value:-41940
# c2_normalized_value:4294925356
# j:103 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6377136111655503
# new_normalized_value:-0.6377136111655503
# fp_normalized_value:-41793
# c2_normalized_value:4294925503
# j:104 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6354707477058553
# new_normalized_value:-0.6354707477058553
# fp_normalized_value:-41646
# c2_normalized_value:4294925650
# j:105 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6332278842461603
# new_normalized_value:-0.6332278842461603
# fp_normalized_value:-41499
# c2_normalized_value:4294925797
# j:106 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6309850207864652
# new_normalized_value:-0.6309850207864652
# fp_normalized_value:-41352
# c2_normalized_value:4294925944
# j:107 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6287421573267703
# new_normalized_value:-0.6287421573267703
# fp_normalized_value:-41205
# c2_normalized_value:4294926091
# j:108 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6264992938670753
# new_normalized_value:-0.6264992938670753
# fp_normalized_value:-41058
# c2_normalized_value:4294926238
# j:109 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6242564304073802
# new_normalized_value:-0.6242564304073802
# fp_normalized_value:-40911
# c2_normalized_value:4294926385
# j:110 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6220135669476853
# new_normalized_value:-0.6220135669476853
# fp_normalized_value:-40764
# c2_normalized_value:4294926532
# j:111 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6197707034879902
# new_normalized_value:-0.6197707034879902
# fp_normalized_value:-40617
# c2_normalized_value:4294926679
# j:112 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6175278400282952
# new_normalized_value:-0.6175278400282952
# fp_normalized_value:-40470
# c2_normalized_value:4294926826
# j:113 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6152849765686003
# new_normalized_value:-0.6152849765686003
# fp_normalized_value:-40323
# c2_normalized_value:4294926973
# j:114 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6130421131089052
# new_normalized_value:-0.6130421131089052
# fp_normalized_value:-40176
# c2_normalized_value:4294927120
# j:115 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6107992496492102
# new_normalized_value:-0.6107992496492102
# fp_normalized_value:-40029
# c2_normalized_value:4294927267
# j:116 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6085563861895152
# new_normalized_value:-0.6085563861895151
# fp_normalized_value:-39882
# c2_normalized_value:4294927414
# j:117 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6063135227298202
# new_normalized_value:-0.6063135227298202
# fp_normalized_value:-39735
# c2_normalized_value:4294927561
# j:118 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6040706592701252
# new_normalized_value:-0.6040706592701252
# fp_normalized_value:-39588
# c2_normalized_value:4294927708
# j:119 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.6018277958104301
# new_normalized_value:-0.6018277958104301
# fp_normalized_value:-39441
# c2_normalized_value:4294927855
# j:120 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.5995849323507352
# new_normalized_value:-0.5995849323507352
# fp_normalized_value:-39294
# c2_normalized_value:4294928002
# j:121 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.5973420688910401
# new_normalized_value:-0.5973420688910401
# fp_normalized_value:-39147
# c2_normalized_value:4294928149
# j:122 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.5950992054313451
# new_normalized_value:-0.5950992054313451
# fp_normalized_value:-39000
# c2_normalized_value:4294928296
# j:123 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.5928563419716502
# new_normalized_value:-0.5928563419716502
# fp_normalized_value:-38853
# c2_normalized_value:4294928443
# j:124 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.5906134785119551
# new_normalized_value:-0.5906134785119551
# fp_normalized_value:-38706
# c2_normalized_value:4294928590
# j:125 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.5883706150522601
# new_normalized_value:-0.5883706150522601
# fp_normalized_value:-38559
# c2_normalized_value:4294928737
# j:126 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.5861277515925651
# new_normalized_value:-0.5861277515925651
# fp_normalized_value:-38412
# c2_normalized_value:4294928884
# j:128 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.581642024673175
# new_normalized_value:-0.581642024673175
# fp_normalized_value:-38118
# c2_normalized_value:4294929178
# j:129 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.5793991612134801
# new_normalized_value:-0.5793991612134801
# fp_normalized_value:-37971
# c2_normalized_value:4294929325
# j:130 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.5771562977537851
# new_normalized_value:-0.5771562977537851
# fp_normalized_value:-37824
# c2_normalized_value:4294929472
# j:131 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.57491343429409
# new_normalized_value:-0.57491343429409
# fp_normalized_value:-37677
# c2_normalized_value:4294929619
# j:132 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.5726705708343951
# new_normalized_value:-0.5726705708343951
# fp_normalized_value:-37530
# c2_normalized_value:4294929766
# j:133 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.5704277073747
# new_normalized_value:-0.5704277073747
# fp_normalized_value:-37383
# c2_normalized_value:4294929913
# j:134 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.568184843915005
# new_normalized_value:-0.568184843915005
# fp_normalized_value:-37236
# c2_normalized_value:4294930060
# j:135 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.5659419804553101
# new_normalized_value:-0.5659419804553101
# fp_normalized_value:-37089
# c2_normalized_value:4294930207
# j:136 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.563699116995615
# new_normalized_value:-0.563699116995615
# fp_normalized_value:-36942
# c2_normalized_value:4294930354
# j:137 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.56145625353592
# new_normalized_value:-0.56145625353592
# fp_normalized_value:-36795
# c2_normalized_value:4294930501
# j:138 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.5592133900762251
# new_normalized_value:-0.5592133900762251
# fp_normalized_value:-36648
# c2_normalized_value:4294930648
# j:139 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.55697052661653
# new_normalized_value:-0.55697052661653
# fp_normalized_value:-36501
# c2_normalized_value:4294930795
# j:140 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.554727663156835
# new_normalized_value:-0.554727663156835
# fp_normalized_value:-36354
# c2_normalized_value:4294930942
# j:141 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.55248479969714
# new_normalized_value:-0.5524847996971399
# fp_normalized_value:-36207
# c2_normalized_value:4294931089
# j:142 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.550241936237445
# new_normalized_value:-0.550241936237445
# fp_normalized_value:-36060
# c2_normalized_value:4294931236
# j:143 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.54799907277775
# new_normalized_value:-0.54799907277775
# fp_normalized_value:-35913
# c2_normalized_value:4294931383
# j:144 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.5457562093180549
# new_normalized_value:-0.5457562093180549
# fp_normalized_value:-35766
# c2_normalized_value:4294931530
# j:145 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.54351334585836
# new_normalized_value:-0.54351334585836
# fp_normalized_value:-35619
# c2_normalized_value:4294931677
# j:146 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.5412704823986649
# new_normalized_value:-0.5412704823986649
# fp_normalized_value:-35472
# c2_normalized_value:4294931824
# j:147 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.5390276189389699
# new_normalized_value:-0.5390276189389699
# fp_normalized_value:-35325
# c2_normalized_value:4294931971
# j:148 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.536784755479275
# new_normalized_value:-0.536784755479275
# fp_normalized_value:-35178
# c2_normalized_value:4294932118
# j:149 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.5345418920195799
# new_normalized_value:-0.5345418920195799
# fp_normalized_value:-35031
# c2_normalized_value:4294932265
# j:150 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.5322990285598849
# new_normalized_value:-0.5322990285598849
# fp_normalized_value:-34884
# c2_normalized_value:4294932412
# j:151 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.5300561651001899
# new_normalized_value:-0.5300561651001899
# fp_normalized_value:-34737
# c2_normalized_value:4294932559
# j:152 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.5278133016404949
# new_normalized_value:-0.5278133016404949
# fp_normalized_value:-34590
# c2_normalized_value:4294932706
# j:153 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.5255704381807998
# new_normalized_value:-0.5255704381807998
# fp_normalized_value:-34443
# c2_normalized_value:4294932853
# j:154 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.5233275747211049
# new_normalized_value:-0.5233275747211049
# fp_normalized_value:-34296
# c2_normalized_value:4294933000
# j:155 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.5210847112614099
# new_normalized_value:-0.5210847112614099
# fp_normalized_value:-34149
# c2_normalized_value:4294933147
# j:157 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.5165989843420199
# new_normalized_value:-0.5165989843420199
# fp_normalized_value:-33855
# c2_normalized_value:4294933441
# j:158 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.5143561208823249
# new_normalized_value:-0.5143561208823249
# fp_normalized_value:-33708
# c2_normalized_value:4294933588
# j:159 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.5121132574226298
# new_normalized_value:-0.5121132574226298
# fp_normalized_value:-33561
# c2_normalized_value:4294933735
# j:160 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.5098703939629349
# new_normalized_value:-0.5098703939629349
# fp_normalized_value:-33414
# c2_normalized_value:4294933882
# j:161 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.5076275305032398
# new_normalized_value:-0.5076275305032398
# fp_normalized_value:-33267
# c2_normalized_value:4294934029
# j:163 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.5031418035838499
# new_normalized_value:-0.5031418035838499
# fp_normalized_value:-32973
# c2_normalized_value:4294934323
# j:164 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.5008989401241548
# new_normalized_value:-0.5008989401241548
# fp_normalized_value:-32826
# c2_normalized_value:4294934470
# j:165 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.49865607666445977
# new_normalized_value:-0.49865607666445977
# fp_normalized_value:-32679
# c2_normalized_value:4294934617
# j:167 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.4941703497450698
# new_normalized_value:-0.4941703497450698
# fp_normalized_value:-32385
# c2_normalized_value:4294934911
# j:168 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.49192748628537475
# new_normalized_value:-0.49192748628537475
# fp_normalized_value:-32238
# c2_normalized_value:4294935058
# j:169 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.48968462282567976
# new_normalized_value:-0.48968462282567976
# fp_normalized_value:-32091
# c2_normalized_value:4294935205
# j:170 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.4874417593659848
# new_normalized_value:-0.4874417593659848
# fp_normalized_value:-31944
# c2_normalized_value:4294935352
# j:171 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.48519889590628973
# new_normalized_value:-0.48519889590628973
# fp_normalized_value:-31797
# c2_normalized_value:4294935499
# j:172 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.48295603244659474
# new_normalized_value:-0.48295603244659474
# fp_normalized_value:-31651
# c2_normalized_value:4294935645
# j:173 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.48071316898689975
# new_normalized_value:-0.4807131689868997
# fp_normalized_value:-31504
# c2_normalized_value:4294935792
# j:174 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.4784703055272047
# new_normalized_value:-0.4784703055272047
# fp_normalized_value:-31357
# c2_normalized_value:4294935939
# j:175 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.4762274420675097
# new_normalized_value:-0.4762274420675097
# fp_normalized_value:-31210
# c2_normalized_value:4294936086
# j:176 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.4739845786078147
# new_normalized_value:-0.4739845786078147
# fp_normalized_value:-31063
# c2_normalized_value:4294936233
# j:178 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.4694988516884247
# new_normalized_value:-0.4694988516884247
# fp_normalized_value:-30769
# c2_normalized_value:4294936527
# j:180 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.46501312476903467
# new_normalized_value:-0.46501312476903467
# fp_normalized_value:-30475
# c2_normalized_value:4294936821
# j:182 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.46052739784964464
# new_normalized_value:-0.46052739784964464
# fp_normalized_value:-30181
# c2_normalized_value:4294937115
# j:183 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.45828453438994965
# new_normalized_value:-0.45828453438994965
# fp_normalized_value:-30034
# c2_normalized_value:4294937262
# j:184 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.45604167093025466
# new_normalized_value:-0.45604167093025466
# fp_normalized_value:-29887
# c2_normalized_value:4294937409
# j:185 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.4537988074705596
# new_normalized_value:-0.4537988074705596
# fp_normalized_value:-29740
# c2_normalized_value:4294937556
# j:186 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.45155594401086463
# new_normalized_value:-0.45155594401086463
# fp_normalized_value:-29593
# c2_normalized_value:4294937703
# j:187 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.4493130805511696
# new_normalized_value:-0.4493130805511696
# fp_normalized_value:-29446
# c2_normalized_value:4294937850
# j:188 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.4470702170914746
# new_normalized_value:-0.4470702170914746
# fp_normalized_value:-29299
# c2_normalized_value:4294937997
# j:189 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.4448273536317796
# new_normalized_value:-0.4448273536317796
# fp_normalized_value:-29152
# c2_normalized_value:4294938144
# j:190 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.44258449017208457
# new_normalized_value:-0.44258449017208457
# fp_normalized_value:-29005
# c2_normalized_value:4294938291
# j:191 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.4403416267123896
# new_normalized_value:-0.4403416267123896
# fp_normalized_value:-28858
# c2_normalized_value:4294938438
# j:192 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.4380987632526946
# new_normalized_value:-0.4380987632526946
# fp_normalized_value:-28711
# c2_normalized_value:4294938585
# j:193 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.43585589979299955
# new_normalized_value:-0.43585589979299955
# fp_normalized_value:-28564
# c2_normalized_value:4294938732
# j:194 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.43361303633330456
# new_normalized_value:-0.43361303633330456
# fp_normalized_value:-28417
# c2_normalized_value:4294938879
# j:195 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.43137017287360957
# new_normalized_value:-0.43137017287360957
# fp_normalized_value:-28270
# c2_normalized_value:4294939026
# j:197 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.42688444595421954
# new_normalized_value:-0.42688444595421954
# fp_normalized_value:-27976
# c2_normalized_value:4294939320
# j:198 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.42464158249452455
# new_normalized_value:-0.42464158249452455
# fp_normalized_value:-27829
# c2_normalized_value:4294939467
# j:199 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.4223987190348295
# new_normalized_value:-0.4223987190348295
# fp_normalized_value:-27682
# c2_normalized_value:4294939614
# j:200 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.4201558555751345
# new_normalized_value:-0.4201558555751345
# fp_normalized_value:-27535
# c2_normalized_value:4294939761
# j:201 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.4179129921154395
# new_normalized_value:-0.4179129921154395
# fp_normalized_value:-27388
# c2_normalized_value:4294939908
# j:202 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.4156701286557445
# new_normalized_value:-0.4156701286557445
# fp_normalized_value:-27241
# c2_normalized_value:4294940055
# j:203 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.4134272651960495
# new_normalized_value:-0.4134272651960495
# fp_normalized_value:-27094
# c2_normalized_value:4294940202
# j:204 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.41118440173635445
# new_normalized_value:-0.41118440173635445
# fp_normalized_value:-26947
# c2_normalized_value:4294940349
# j:205 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.40894153827665947
# new_normalized_value:-0.40894153827665947
# fp_normalized_value:-26800
# c2_normalized_value:4294940496
# j:206 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.4066986748169645
# new_normalized_value:-0.4066986748169645
# fp_normalized_value:-26653
# c2_normalized_value:4294940643
# j:207 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.40445581135726943
# new_normalized_value:-0.40445581135726943
# fp_normalized_value:-26506
# c2_normalized_value:4294940790
# j:208 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.40221294789757445
# new_normalized_value:-0.40221294789757445
# fp_normalized_value:-26359
# c2_normalized_value:4294940937
# j:209 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.39997008443787946
# new_normalized_value:-0.39997008443787946
# fp_normalized_value:-26212
# c2_normalized_value:4294941084
# j:210 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.3977272209781844
# new_normalized_value:-0.3977272209781844
# fp_normalized_value:-26065
# c2_normalized_value:4294941231
# j:211 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.3954843575184894
# new_normalized_value:-0.3954843575184894
# fp_normalized_value:-25918
# c2_normalized_value:4294941378
# j:212 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.3932414940587944
# new_normalized_value:-0.3932414940587944
# fp_normalized_value:-25771
# c2_normalized_value:4294941525
# j:213 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.3909986305990994
# new_normalized_value:-0.3909986305990994
# fp_normalized_value:-25624
# c2_normalized_value:4294941672
# j:214 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.3887557671394044
# new_normalized_value:-0.3887557671394044
# fp_normalized_value:-25477
# c2_normalized_value:4294941819
# j:215 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.38651290367970936
# new_normalized_value:-0.38651290367970936
# fp_normalized_value:-25330
# c2_normalized_value:4294941966
# j:216 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.3842700402200144
# new_normalized_value:-0.3842700402200144
# fp_normalized_value:-25183
# c2_normalized_value:4294942113
# j:217 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.3820271767603194
# new_normalized_value:-0.3820271767603194
# fp_normalized_value:-25036
# c2_normalized_value:4294942260
# j:218 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.37978431330062434
# new_normalized_value:-0.37978431330062434
# fp_normalized_value:-24889
# c2_normalized_value:4294942407
# j:219 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.37754144984092936
# new_normalized_value:-0.37754144984092936
# fp_normalized_value:-24742
# c2_normalized_value:4294942554
# j:220 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.37529858638123437
# new_normalized_value:-0.37529858638123437
# fp_normalized_value:-24595
# c2_normalized_value:4294942701
# j:221 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.3730557229215393
# new_normalized_value:-0.3730557229215393
# fp_normalized_value:-24448
# c2_normalized_value:4294942848
# j:222 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.37081285946184434
# new_normalized_value:-0.37081285946184434
# fp_normalized_value:-24301
# c2_normalized_value:4294942995
# j:223 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.36856999600214935
# new_normalized_value:-0.36856999600214935
# fp_normalized_value:-24154
# c2_normalized_value:4294943142
# j:224 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.3663271325424543
# new_normalized_value:-0.3663271325424543
# fp_normalized_value:-24007
# c2_normalized_value:4294943289
# j:226 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.36184140562306427
# new_normalized_value:-0.36184140562306427
# fp_normalized_value:-23713
# c2_normalized_value:4294943583
# j:227 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.3595985421633693
# new_normalized_value:-0.3595985421633693
# fp_normalized_value:-23566
# c2_normalized_value:4294943730
# j:229 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.35511281524397925
# new_normalized_value:-0.35511281524397925
# fp_normalized_value:-23272
# c2_normalized_value:4294944024
# j:230 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.35286995178428426
# new_normalized_value:-0.35286995178428426
# fp_normalized_value:-23125
# c2_normalized_value:4294944171
# j:231 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0.3506270883245893
# new_normalized_value:-0.3506270883245893
# fp_normalized_value:-22978
# c2_normalized_value:4294944318
# j:232 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:-0
,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:1.892236371370419
# new_normalized_value:1.892236371370419
# fp_normalized_value:124009
# c2_normalized_value:124009
# j:1248 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:1.9303650501852339
# new_normalized_value:1.9303650501852339
# fp_normalized_value:126508
# c2_normalized_value:126508
# j:1260 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:1.9572794117015742
# new_normalized_value:1.9572794117015742
# fp_normalized_value:128272
# c2_normalized_value:128272
# j:1264 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:1.966250865540354
# new_normalized_value:1.966250865540354
# fp_normalized_value:128860
# c2_normalized_value:128860
# j:1273 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:1.9864366366776092
# new_normalized_value:1.9864366366776092
# fp_normalized_value:130183
# c2_normalized_value:130183
# j:1300 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:2.0469939500893743
# new_normalized_value:2.0469939500893743
# fp_normalized_value:134151
# c2_normalized_value:134151
# j:1308 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:2.0649368577669343
# new_normalized_value:2.0649368577669343
# fp_normalized_value:135327
# c2_normalized_value:135327
# j:1315 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:2.0806369019847994
# new_normalized_value:2.0806369019847994
# fp_normalized_value:136356
# c2_normalized_value:136356
# j:1319 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:2.0896083558235796
# new_normalized_value:2.0896083558235796
# fp_normalized_value:136944
# c2_normalized_value:136944
# j:1342 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:2.1411942153965646
# new_normalized_value:2.1411942153965646
# fp_normalized_value:140325
# c2_normalized_value:140325
# j:1348 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:2.1546513961547347
# new_normalized_value:2.1546513961547347
# fp_normalized_value:141207
# c2_normalized_value:141207
# j:1360 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:2.1815657576710747
# new_normalized_value:2.1815657576710747
# fp_normalized_value:142971
# c2_normalized_value:142971
# j:1361 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:2.18380862113077
# new_normalized_value:2.18380862113077
# fp_normalized_value:143118
# c2_normalized_value:143118
# j:1368 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:2.199508665348635
# new_normalized_value:2.199508665348635
# fp_normalized_value:144146
# c2_normalized_value:144146
# j:1372 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:2.208480119187415
# new_normalized_value:2.208480119187415
# fp_normalized_value:144734
# c2_normalized_value:144734
# j:1380 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:2.226423026864975
# new_normalized_value:2.226423026864975
# fp_normalized_value:145910
# c2_normalized_value:145910
# j:1420 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:2.316137565252775
# new_normalized_value:2.316137565252775
# fp_normalized_value:151790
# c2_normalized_value:151790
# j:1425 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:2.3273518825512505
# new_normalized_value:2.3273518825512505
# fp_normalized_value:152525
# c2_normalized_value:152525
# j:1448 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:2.3789377421242355
# new_normalized_value:2.3789377421242355
# fp_normalized_value:155906
# c2_normalized_value:155906
# j:1452 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:2.3879091959630157
# new_normalized_value:2.3879091959630157
# fp_normalized_value:156494
# c2_normalized_value:156494
# j:1460 ,weights[i]:387.3301086425781, math.sqrt(biases[i]:445.8586168843213
# normalized_value:2.4058521036405756
# new_normalized_value:2.4058521036405756
# fp_normalized_value:157669
# c2_normalized_value:157669

# %% [markdown]
# ### Topology file generator for s5x

# %%
weights = hidden_layer_weights
biases = hidden_layer_biases
expected_stimuli = sum([1<<(i + 1) for i in range(number_of_attributes)])

for i in range(hidden_layer_nodes):
  s5x_id = 51+i
  s5x_entries = {
    "target": "bmv2",
    "p4info": "build/ANN.p4.p4info.txt",
    "bmv2_json": "build/ANN.json",
    "table_entries": [
      {
        "table": "MyIngress.tab_neuron_id",
        "default_action": True,
        "action_name": "MyIngress.set_neuron_id",
        "action_params": {
          "neuron_id": s5x_id
        }
      },
      {
        "table": "MyIngress.tab_n_expected_stimuli",
        "default_action": True,
        "action_name": "MyIngress.set_n_expected_stimuli",
        "action_params": {
          "n_expected_stimuli": number_of_attributes
        }
      },
      {
        "table": "MyIngress.tab_expected_stimuli",
        "default_action": True,
        "action_name": "MyIngress.set_expected_stimuli",
        "action_params": {
          "expected_stimuli": expected_stimuli
        }
      },
      {
        "table": "MyIngress.tab_agg_func",
        "default_action": True,
        "action_name": "MyIngress.set_agg_func",
        "action_params": {
          "agg_func": 1
        }
      },
      {
        "table": "MyIngress.tab_activation_func",
        "default_action": True,
        "action_name": "MyIngress.set_activation_func",
        "action_params": {
          "activation_func": 3
        }
      }
    ],
    "multicast_group_entries":[
      {
        "multicast_group_id" : s5x_id,
        "replicas":[]
      }
    ]
  }

  for h in range(output_layer_nodes):
    s5x_entries["multicast_group_entries"][0]["replicas"].append(
      {
        "egress_port" :101+h,
        "instance": 1
      }
    )

  fp_value = int(biases[i] * (2**PRECISION))
  c2_value = num_to_c2(fp_value, n_bits)
  s5x_entries["table_entries"].append(
    {
      "table": "MyIngress.tab_neuron_bias",
      "default_action": True,
      "action_name": "MyIngress.set_neuron_bias",
      "action_params": {
        "neuron_bias": c2_value
      }
    },
  )
  for j in range(number_of_attributes):
    fp_value = int(weights[j][i] * (2**PRECISION))
    c2_value = num_to_c2(fp_value, n_bits)
    s5x_entries["table_entries"].append(
      {
        "table": "MyIngress.tab_n2n_weight",
        "match": {
          "hdr.ann.neuron_id": j+1
        },
        "action_name": "MyIngress.set_n2n_weight",
        "action_params": {
          "n2n_weight":  c2_value
        }
      },
    )
    s5x_entries["table_entries"].append(
      {
        "table": "MyIngress.ann_forward",
        "match": {
          "standard_metadata.ingress_port": j+1
        },
        "action_name": "MyIngress.mcast",
        "action_params": {
          "mgroup": s5x_id
        }
      }
    )
  s5x_file_title = "/content/drive/MyDrive/network-traffic-classification-main/code/topology/s%d"%s5x_id + "-runtime.json"
  with open(s5x_file_title, "w") as f:
    json.dump(s5x_entries, f, indent = 2)

print(json.dumps(s5x_entries, indent = 2))
# Out:
# {
#   "target": "bmv2",
#   "p4info": "build/ANN.p4.p4info.txt",
#   "bmv2_json": "build/ANN.json",
#   "table_entries": [
#     {
#       "table": "MyIngress.tab_neuron_id",
#       "default_action": true,
#       "action_name": "MyIngress.set_neuron_id",
#       "action_params": {
#         "neuron_id": 52
#       }
#     },
#     {
#       "table": "MyIngress.tab_n_expected_stimuli",
#       "default_action": true,
#       "action_name": "MyIngress.set_n_expected_stimuli",
#       "action_params": {
#         "n_expected_stimuli": 2
#       }
#     },
#     {
#       "table": "MyIngress.tab_expected_stimuli",
#       "default_action": true,
#       "action_name": "MyIngress.set_expected_stimuli",
#       "action_params": {
#         "expected_stimuli": 6
#       }
#     },
#     {
#       "table": "MyIngress.tab_agg_func",
#       "default_action": true,
#       "action_name": "MyIngress.set_agg_func",
#       "action_params": {
#         "agg_func": 1
#       }
#     },
#     {
#       "table": "MyIngress.tab_activation_func",
#       "default_action": true,
#       "action_name": "MyIngress.set_activation_func",
#       "action_params": {
#         "activation_func": 3
#       }
#     },
#     {
#       "table": "MyIngress.tab_neuron_bias",
#       "default_action": true,
#       "action_name": "MyIngress.set_neuron_bias",
#       "action_params": {
#         "neuron_bias": 92624
#       }
#     },
#     {
#       "table": "MyIngress.tab_n2n_weight",
#       "match": {
#         "hdr.ann.neuron_id": 1
#       },
#       "action_name": "MyIngress.set_n2n_weight",
#       "action_params": {
#         "n2n_weight": 10518
#       }
#     },
#     {
#       "table": "MyIngress.ann_forward",
#       "match": {
#         "standard_metadata.ingress_port": 1
#       },
#       "action_name": "MyIngress.mcast",
#       "action_params": {
#         "mgroup": 52
#       }
#     },
#     {
#       "table": "MyIngress.tab_n2n_weight",
#       "match": {
#         "hdr.ann.neuron_id": 2
#       },
#       "action_name": "MyIngress.set_n2n_weight",
#       "action_params": {
#         "n2n_weight": 110038
#       }
#     },
#     {
#       "table": "MyIngress.ann_forward",
#       "match": {
#         "standard_metadata.ingress_port": 2
#       },
#       "action_name": "MyIngress.mcast",
#       "action_params": {
#         "mgroup": 52
#       }
#     }
#   ],
#   "multicast_group_entries": [
#     {
#       "multicast_group_id": 52,
#       "replicas": [
#         {
#           "egress_port": 101,
#           "instance": 1
#         },
#         {
#           "egress_port": 102,
#           "instance": 1
#         }
#       ]
#     }
#   ]
# }

# %%
# #expected stimuli
# #hidden
# sum([1<<(i + 1) for i in range(n)])

# #output
# sum([1<<(i + 51) for i in range(n)])




# #expected stimuli
# import sys

# def main(neurons):
#     neurons = [int(x) for x in neurons.split(",")]
#     expected_stimuli = 0
#     for x in neurons:
#         expected_stimuli = expected_stimuli | 1 << x

#     print("dec:", expected_stimuli)
#     print("bin:", bin(expected_stimuli))

# if __name__ == '__main__':
#     main(sys.argv[1])

# #6
# #15762598695796736

# %% [markdown]
# ### Topology file generator for s1xx

# %%
expected_stimuli = sum([1<<(i + 101) for i in range(2)])
print(expected_stimuli)
# Out:
# 7605903601369376408980219232256

# %%
weights = out_layer_weights
biases = out_layer_biases
expected_stimuli = sum([1<<(i + 51) for i in range(hidden_layer_nodes)])

for i in range(output_layer_nodes):
  s1xx_id = 101+i
  s1xx_entries = {
    "target": "bmv2",
    "p4info": "build/ANN.p4.p4info.txt",
    "bmv2_json": "build/ANN.json",
    "table_entries": [
      {
        "table": "MyIngress.tab_neuron_id",
        "default_action": True,
        "action_name": "MyIngress.set_neuron_id",
        "action_params": {
          "neuron_id": s1xx_id
        }
      },
      {
        "table": "MyIngress.tab_n_expected_stimuli",
        "default_action": True,
        "action_name": "MyIngress.set_n_expected_stimuli",
        "action_params": {
          "n_expected_stimuli": hidden_layer_nodes
        }
      },
      {
        "table": "MyIngress.tab_expected_stimuli",
        "default_action": True,
        "action_name": "MyIngress.set_expected_stimuli",
        "action_params": {
          "expected_stimuli": expected_stimuli

        }
      },
      {
        "table": "MyIngress.tab_agg_func",
        "default_action": True,
        "action_name": "MyIngress.set_agg_func",
        "action_params": {
          "agg_func": 1
        }
      },
      {
        "table": "MyIngress.tab_activation_func",
        "default_action": True,
        "action_name": "MyIngress.set_activation_func",
        "action_params": {
          "activation_func": 2
        }
      }
    ],
    "multicast_group_entries":[
      {
        "multicast_group_id" : s1xx_id,
        "replicas":[
          {
            "egress_port" :126,
            "instance": 1
          }
        ]
      }
    ]
  }

  fp_value = int(biases[i] * (2**PRECISION))
  c2_value = num_to_c2(fp_value, n_bits)
  s1xx_entries["table_entries"].append(
    {
      "table": "MyIngress.tab_neuron_bias",
      "default_action": True,
      "action_name": "MyIngress.set_neuron_bias",
      "action_params": {
        "neuron_bias": c2_value
      }
    },
  )

  for j in range(hidden_layer_nodes):
    fp_value = int(weights[j][i] * (2**PRECISION))
    c2_value = num_to_c2(fp_value, n_bits)
    s1xx_entries["table_entries"].append(
      {
        "table": "MyIngress.tab_n2n_weight",
        "match": {
          "hdr.ann.neuron_id": j+51
        },
        "action_name": "MyIngress.set_n2n_weight",
        "action_params": {
          "n2n_weight":  c2_value
        }
      }
    )
    s1xx_entries["table_entries"].append(
      {
        "table": "MyIngress.ann_forward",
        "match": {
          "standard_metadata.ingress_port": j+51
        },
        "action_name": "MyIngress.mcast",
        "action_params": {
          "mgroup": s1xx_id
        }
      }
    )

  #print(s1xx_entries["table_entries"])
  s1xx_file_title = "/content/drive/MyDrive/network-traffic-classification-main/code/topology/s%d"%s1xx_id + "-runtime.json"
  with open(s1xx_file_title, "w") as f:
    json.dump(s1xx_entries, f, indent = 2)

print(json.dumps(s1xx_entries, indent = 2))
# Out:
# {
#   "target": "bmv2",
#   "p4info": "build/ANN.p4.p4info.txt",
#   "bmv2_json": "build/ANN.json",
#   "table_entries": [
#     {
#       "table": "MyIngress.tab_neuron_id",
#       "default_action": true,
#       "action_name": "MyIngress.set_neuron_id",
#       "action_params": {
#         "neuron_id": 102
#       }
#     },
#     {
#       "table": "MyIngress.tab_n_expected_stimuli",
#       "default_action": true,
#       "action_name": "MyIngress.set_n_expected_stimuli",
#       "action_params": {
#         "n_expected_stimuli": 2
#       }
#     },
#     {
#       "table": "MyIngress.tab_expected_stimuli",
#       "default_action": true,
#       "action_name": "MyIngress.set_expected_stimuli",
#       "action_params": {
#         "expected_stimuli": 6755399441055744
#       }
#     },
#     {
#       "table": "MyIngress.tab_agg_func",
#       "default_action": true,
#       "action_name": "MyIngress.set_agg_func",
#       "action_params": {
#         "agg_func": 1
#       }
#     },
#     {
#       "table": "MyIngress.tab_activation_func",
#       "default_action": true,
#       "action_name": "MyIngress.set_activation_func",
#       "action_params": {
#         "activation_func": 2
#       }
#     },
#     {
#       "table": "MyIngress.tab_neuron_bias",
#       "default_action": true,
#       "action_name": "MyIngress.set_neuron_bias",
#       "action_params": {
#         "neuron_bias": 156151
#       }
#     },
#     {
#       "table": "MyIngress.tab_n2n_weight",
#       "match": {
#         "hdr.ann.neuron_id": 51
#       },
#       "action_name": "MyIngress.set_n2n_weight",
#       "action_params": {
#         "n2n_weight": 4294684454
#       }
#     },
#     {
#       "table": "MyIngress.ann_forward",
#       "match": {
#         "standard_metadata.ingress_port": 51
#       },
#       "action_name": "MyIngress.mcast",
#       "action_params": {
#         "mgroup": 102
#       }
#     },
#     {
#       "table": "MyIngress.tab_n2n_weight",
#       "match": {
#         "hdr.ann.neuron_id": 52
#       },
#       "action_name": "MyIngress.set_n2n_weight",
#       "action_params": {
#         "n2n_weight": 4294790003
#       }
#     },
#     {
#       "table": "MyIngress.ann_forward",
#       "match": {
#         "standard_metadata.ingress_port": 52
#       },
#       "action_name": "MyIngress.mcast",
#       "action_params": {
#         "mgroup": 102
#       }
#     }
#   ],
#   "multicast_group_entries": [
#     {
#       "multicast_group_id": 102,
#       "replicas": [
#         {
#           "egress_port": 126,
#           "instance": 1
#         }
#       ]
#     }
#   ]
# }

# %% [markdown]
# ### Topology file generator for topology.json

# %%
#definition of topology
topology = {
    'hosts': {
        'h1': {'ip': '10.0.1.1/24', 'mac': '08:00:00:00:01:11',
                'commands':['route add default gw 10.0.1.10 dev eth0',
                            'arp -i eth0 -s 10.0.1.10 08:00:00:00:01:00']},
        'h2': {'ip': '10.0.2.2/24', 'mac': '08:00:00:00:02:22',
                'commands':['route add default gw 10.0.2.20 dev eth0',
                            'arp -i eth0 -s 10.0.2.20 08:00:00:00:02:00']}
    },
    'switches': {},
    'links': []
}

#populate switches dict
for i in range(number_of_attributes):
  switch_name = 's%d'%(i+1)
  switch_content = { 'runtime_json' : 'topology/s%d'%(i+1) +'-runtime.json' }
  topology['switches'][switch_name] = switch_content

for i in range(hidden_layer_nodes):
  switch_name = 's%d'%(i+51)
  switch_content = { 'runtime_json' : 'topology/s%d'%(i+51) +'-runtime.json' }
  topology['switches'][switch_name] = switch_content

for i in range(output_layer_nodes):
  switch_name = 's%d'%(i+101)
  switch_content = { 'runtime_json' : 'topology/s%d'%(i+101) +'-runtime.json' }
  topology['switches'][switch_name] = switch_content

topology['switches']['s126'] = { 'runtime_json' : 'topology/s126-runtime.json' }

#populate links list
for i in range(number_of_attributes):
  topology['links'].append(["h1", "s%d"%(i+1)+"-p1"])

for i in range(number_of_attributes):
  for j in range(hidden_layer_nodes):
    topology['links'].append(["s%d"%(i+1)+"-p%d"%(j+51), "s%d"%(j+51)+"-p%d"%(i+1)])

for i in range(hidden_layer_nodes):
  for j in range(output_layer_nodes):
    topology['links'].append(["s%d"%(i+51)+"-p%d"%(j+101), "s%d"%(j+101)+"-p%d"%(i+51)])

for i in range(output_layer_nodes):
  topology['links'].append(["s%d"%(i+101)+"-p126", "s126-p%d"%(i+101)])

topology['links'].append(["s126-p2", "h2"])

display(topology)

topology_title = "/content/drive/MyDrive/network-traffic-classification-main/code/topology/topology.json"
with open(topology_title, "w") as f:
  json.dump(topology, f, indent = 2)
# Out:
# {'hosts': {'h1': {'ip': '10.0.1.1/24',
#    'mac': '08:00:00:00:01:11',
#    'commands': ['route add default gw 10.0.1.10 dev eth0',
#     'arp -i eth0 -s 10.0.1.10 08:00:00:00:01:00']},
#   'h2': {'ip': '10.0.2.2/24',
#    'mac': '08:00:00:00:02:22',
#    'commands': ['route add default gw 10.0.2.20 dev eth0',
#     'arp -i eth0 -s 10.0.2.20 08:00:00:00:02:00']}},
#  'switches': {'s1': {'runtime_json': 'topology/s1-runtime.json'},
#   's2': {'runtime_json': 'topology/s2-runtime.json'},
#   's51': {'runtime_json': 'topology/s51-runtime.json'},
#   's52': {'runtime_json': 'topology/s52-runtime.json'},
#   's101': {'runtime_json': 'topology/s101-runtime.json'},
#   's102': {'runtime_json': 'topology/s102-runtime.json'},
#   's126': {'runtime_json': 'topology/s126-runtime.json'}},
#  'links': [['h1', 's1-p1'],
#   ['h1', 's2-p1'],
#   ['s1-p51', 's51-p1'],
#   ['s1-p52', 's52-p1'],
#   ['s2-p51', 's51-p2'],
#   ['s2-p52', 's52-p2'],
#   ['s51-p101', 's101-p51'],
#   ['s51-p102', 's102-p51'],
#   ['s52-p101', 's101-p52'],
#   ['s52-p102', 's102-p52'],
#   ['s101-p126', 's126-p101'],
#   ['s102-p126', 's126-p102'],
#   ['s126-p2', 'h2']]}

# %% [markdown]
# ### Jinja template to generate ann.p4, ann-header.py and ann_tester.py

# %%
environment = Environment(loader=FileSystemLoader("/content/drive/MyDrive/network-traffic-classification-main/jinja/templates/"))
template = environment.get_template("ANN_tester_b.py")
content = template.render(
    wordsize= wordsize,
    precision= precision,
    integer= wordsize - precision,
    fraction = precision,
    slack = slack,
    df_number = df_number,
    number_of_attributes = number_of_attributes

)
filename = "/content/drive/MyDrive/network-traffic-classification-main/code/ANN_tester_b.py"
with open(filename, mode="w", encoding="utf-8") as message:
    message.write(content)
    print(f"... wrote {filename}")

###################################################
template = environment.get_template("ANN_hdrs.py")
content = template.render(
    wordsize= wordsize,
    slack = slack,
)
filename = "/content/drive/MyDrive/network-traffic-classification-main/code/ANN_hdrs.py"
with open(filename, mode="w", encoding="utf-8") as message:
    message.write(content)
    print(f"... wrote {filename}")

###################################################
template = environment.get_template("ANN.p4")
content = template.render(
    wordsize= wordsize,
    precision= precision,
    double = wordsize*2,
    slack = slack,
)
filename = "/content/drive/MyDrive/network-traffic-classification-main/code/ANN.p4"
with open(filename, mode="w", encoding="utf-8") as message:
    message.write(content)
    print(f"... wrote {filename}")
# Out:
# ... wrote /content/drive/MyDrive/network-traffic-classification-main/code/ANN_tester_b.py
# ... wrote /content/drive/MyDrive/network-traffic-classification-main/code/ANN_hdrs.py
# ... wrote /content/drive/MyDrive/network-traffic-classification-main/code/ANN.p4
