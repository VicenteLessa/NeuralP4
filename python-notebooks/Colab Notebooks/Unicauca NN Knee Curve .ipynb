# %%
#
from datetime import datetime
import json
import matplotlib.pyplot as plt
import numpy as np

# %%
#test
accuracies = [73.23, 75.19, 77.18, 80.86]
#train
accuracies2 = [72.91, 74.87, 76.23, 79.45 ]

# %%
print(accuracies)
max_acc = max(accuracies2)
min_acc = min(accuracies)
len_acc = len(accuracies)

xc = range(len_acc)
plt.figure(figsize=[8, 6])
plt.plot(xc, accuracies)
plt.plot(xc, accuracies2)


plt.ylabel('Acurácias de treino e teste (%).')
plt.xlabel('Número de neurônios nas camadas de entrada e oculta.')
plt.title('Acurácias de treino e teste com diferentes modelos.')
plt.legend()

# y=np.arange(0.05,0.9,0.025)
# z=np.arange(min_acc,max_acc,0.005)

# plt.xticks(range(len(accuracies)+2))
# plt.yticks(y)
# plt.ylim(min_acc-0.0025, max_acc+0.0025)

# for i in y:
#   plt.axhline(i, color="black", linestyle=":")
# for i in range(len_acc):
#   plt.axvline(i, color="black", linestyle=":")

plt.legend(loc=2)

# Date for report file
# now = datetime.now()
# dt_string = now.strftime("%d-%m-%Y %H:%M:%S")
# title = "/content/drive/MyDrive/network-traffic-classification-main/nn-reports/KneeCurve_%s"%dt_string + ".pdf"
# plt.savefig(title)
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [73.23, 75.19, 77.18, 80.86]
