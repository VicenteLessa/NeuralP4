# %%
from google.colab import drive
drive.mount('/content/drive')
from datetime import datetime
import json
import numpy as np
import os
import pandas as pd
import sys
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split


from keras.callbacks import History
history = History()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Specify here the NN topology and the dataframe to be loaded

# %%
#specify the NN topology here:
#input_layer_nodes = number_of_attributes
number_of_attributes = 16
hidden_layer_nodes = 32
output_layer_nodes = 3
BATCH_SIZE = 10
EPOCHS = 10
#specify the dataset here:
#choose the dataframe which the NN will be trained and mo
#df_number = 1
#number_of_samples = 2000

# %% [markdown]
# ###Define the model

# %%
def get_basic_model():
  model = tf.keras.Sequential([
    normalizer,
    tf.keras.layers.Dense(hidden_layer_nodes, activation='relu'),
    tf.keras.layers.Dense(output_layer_nodes)
  ])

  model.compile(optimizer='adam',
                loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy'])
  return model

# %%
features = pd.read_csv('/content/drive/MyDrive/nprint/nn-reproduction/country-of-origin/features.csv')

# %%
display(features)
features_37 = features[[,"pkt_1_ipv4_id_12","pkt_3_ipv4_tl_5","pkt_1_ipv4_ttl_4","pkt_2_ipv4_cksum_15","pkt_3_ipv4_dfbit_0","pkt_0_udp_cksum_2","pkt_3_ipv4_cksum_14","pkt_2_ipv4_ttl_6","pkt_1_udp_cksum_12","pkt_4_ipv4_cksum_13","pkt_3_ipv4_id_15","pkt_0_udp_sport_11","pkt_0_ipv4_ttl_1","pkt_1_ipv4_ttl_3","pkt_4_ipv4_id_13","pkt_0_ipv4_id_2","pkt_1_udp_len_15","pkt_1_udp_cksum_2","pkt_2_ipv4_ttl_3","pkt_3_udp_cksum_11","pkt_4_ipv4_cksum_7","pkt_2_ipv4_cksum_3","pkt_0_udp_cksum_5","pkt_0_ipv4_cksum_0","pkt_0_ipv4_tos_6","pkt_1_ipv4_cksum_4","pkt_3_ipv4_id_8","pkt_4_ipv4_id_3","pkt_2_ipv4_cksum_9","pkt_1_udp_sport_2","pkt_1_ipv4_id_2","pkt_3_ipv4_id_3","pkt_0_udp_len_12","pkt_0_ipv4_tl_15","pkt_1_ipv4_cksum_10","pkt_3_udp_len_15","pkt_0_udp_len_15"]]
label_37 = features[["label"]]
display(label_37)

# %%
label_37.to_csv(r'/content/drive/MyDrive/nprint/nn-reproduction/country-of-origin/label_37.csv')

# %%
# for value in label_37:
#   if value == "us":
#     value = 0
#   if value == "china":
#     value = 1
#   if value == "india":
#     value = 2

label_37 = pd.read_csv('/content/drive/MyDrive/nprint/nn-reproduction/country-of-origin/int_label_37.csv', index_col=0)
display(label_37.head(10))
# Out:
#    label
# 0      2
# 1      0
# 2      2
# 3      1
# 4      1
# 5      0
# 6      2
# 7      0
# 8      0
# 9      2

# %%
df_train, df_test, label_train, label_test = train_test_split(features_37, label_37, test_size=0.25, random_state=42)

# %% [markdown]
# ###Import the data

# %%
# df_train = pd.read_pickle('/content/drive/MyDrive/nprint/nn-reproduction/country-of-origin/X.pkl')
# df_test = pd.read_pickle('/content/drive/MyDrive/nprint/nn-reproduction/country-of-origin/X_val.pkl')
# label_train = pd.read_pickle('/content/drive/MyDrive/nprint/nn-reproduction/country-of-origin/y.pkl')
# label_test = pd.read_pickle('/content/drive/MyDrive/nprint/nn-reproduction/country-of-origin/y_val.pkl')

# df = pd.DataFrame(df_train)
# df.to_csv(r'/content/drive/MyDrive/nprint/nn-reproduction/country-of-origin/X.csv')
# df = pd.DataFrame(df_test)
# df.to_csv(r'/content/drive/MyDrive/nprint/nn-reproduction/country-of-origin/X_val.csv')
# df = pd.DataFrame(label_train)
# df.to_csv(r'/content/drive/MyDrive/nprint/nn-reproduction/country-of-origin/y.csv')
# df = pd.DataFrame(label_test)
# df.to_csv(r'/content/drive/MyDrive/nprint/nn-reproduction/country-of-origin/y_val.csv')

# %%
df_train = pd.read_csv('/content/drive/MyDrive/nprint/nn-reproduction/country-of-origin/X.csv')
df_test = pd.read_csv('/content/drive/MyDrive/nprint/nn-reproduction/country-of-origin/X_val.csv')
label_train = pd.read_csv('/content/drive/MyDrive/nprint/nn-reproduction/country-of-origin/y.csv')
label_test = pd.read_csv('/content/drive/MyDrive/nprint/nn-reproduction/country-of-origin/y_val.csv')

# %%
display(df_train)
display(df_test)
display(label_train)
display(label_test)
# Out:
#      pkt_1_ipv4_id_12  pkt_3_ipv4_tl_5  pkt_1_ipv4_ttl_4  pkt_2_ipv4_cksum_15  \
# 304                 1                0                 1                    1
# 3                   0                0                 1                    0
# 18                  0                0                 1                    0
# 325                 1                0                 1                    0
# 60                  1                0                 0                    1
# ..                ...              ...               ...                  ...
# 71                  1                0                 1                    1
# 106                 0                0                 0                    0
# 270                 1                0                 0                    1
# 348                 1                0                 1                    0
# 102                 1                0                 1                    0
#
#      pkt_3_ipv4_dfbit_0  pkt_0_udp_cksum_2  pkt_3_ipv4_cksum_14  \
# 304                   1                  1                    1
# 3                     1                 -1                    1
# 18                    0                  0                    1
# 325                   1                 -1                    0
# 60                    0                  0                    0
# ..                  ...                ...                  ...
# 71                    1                 -1                    1
# 106                   1                  1                    1
# 270                   0                  1                    0
# 348                   1                  1                    0
# 102                   0                  1                    1
#
#      pkt_2_ipv4_ttl_6  pkt_1_udp_cksum_12  pkt_4_ipv4_cksum_13  ...  \
# 304                 0                  -1                    1  ...
# 3                   1                  -1                    0  ...
# 18                  1                   1                    0  ...
# 325                 0                  -1                    1  ...
# 60                  1                   1                    1  ...
# ..                ...                 ...                  ...  ...
# 71                  1                   1                    1  ...
# 106                 1                   0                    1  ...
# 270                 1                   0                    0  ...
# 348                 0                  -1                    1  ...
# 102                 1                   1                    0  ...
#
#      pkt_4_ipv4_id_3  pkt_2_ipv4_cksum_9  pkt_1_udp_sport_2  pkt_1_ipv4_id_2  \
# 304                0                   0                 -1                1
# 3                  0                   1                 -1                0
# 18                 0                   0                  1                1
# 325                1                   0                 -1                0
# 60                 0                   0                  0                0
# ..               ...                 ...                ...              ...
# 71                 0                   1                  0                0
# 106                0                   0                  0                1
# 270                1                   0                  0                0
# 348                0                   0                 -1                0
# 102                0                   0                  0                1
#
#      pkt_3_ipv4_id_3  pkt_0_udp_len_12  pkt_0_ipv4_tl_15  pkt_1_ipv4_cksum_10  \
# 304                1                 0                 1                    0
# 3                  0                -1                 0                    0
# 18                 0                 1                 1                    0
# 325                1                -1                 0                    0
# 60                 1                 1                 0                    1
# ..               ...               ...               ...                  ...
# 71                 0                -1                 0                    0
# 106                0                 1                 0                    0
# 270                1                 1                 0                    1
# 348                1                 1                 1                    0
# 102                1                 0                 0                    0
#
#      pkt_3_udp_len_15  pkt_0_udp_len_15
# 304                -1                 1
# 3                  -1                -1
# 18                  1                 1
# 325                -1                -1
# 60                  0                 0
# ..                ...               ...
# 71                  1                -1
# 106                -1                 0
# 270                 0                 0
# 348                -1                 1
# 102                 0                 0
#
# [318 rows x 37 columns]
#      pkt_1_ipv4_id_12  pkt_3_ipv4_tl_5  pkt_1_ipv4_ttl_4  pkt_2_ipv4_cksum_15  \
# 417                 0                0                 0                    0
# 75                  0                0                 1                    0
# 176                 1                0                 1                    1
# 30                  0                0                 0                    1
# 357                 0                0                 1                    0
# ..                ...              ...               ...                  ...
# 366                 1                0                 0                    0
# 398                 0                0                 0                    1
# 16                  0                0                 0                    0
# 393                 1                0                 0                    1
# 131                 1                0                 0                    1
#
#      pkt_3_ipv4_dfbit_0  pkt_0_udp_cksum_2  pkt_3_ipv4_cksum_14  \
# 417                   1                  0                    0
# 75                    0                  1                    1
# 176                   0                  0                    1
# 30                    0                  1                    0
# 357                   0                  1                    0
# ..                  ...                ...                  ...
# 366                   0                  0                    1
# 398                   1                  0                    0
# 16                    1                 -1                    1
# 393                   1                  1                    0
# 131                   1                  0                    0
#
#      pkt_2_ipv4_ttl_6  pkt_1_udp_cksum_12  pkt_4_ipv4_cksum_13  ...  \
# 417                 1                   0                    0  ...
# 75                  1                   0                    0  ...
# 176                 1                   1                    0  ...
# 30                  1                   0                    0  ...
# 357                 0                  -1                    0  ...
# ..                ...                 ...                  ...  ...
# 366                 1                   1                    0  ...
# 398                 1                   1                    1  ...
# 16                  1                  -1                    0  ...
# 393                 1                   0                    1  ...
# 131                 1                   0                    0  ...
#
#      pkt_4_ipv4_id_3  pkt_2_ipv4_cksum_9  pkt_1_udp_sport_2  pkt_1_ipv4_id_2  \
# 417                1                   0                  0                0
# 75                 0                   0                  0                1
# 176                1                   0                  1                0
# 30                 0                   0                  0                1
# 357                0                   0                 -1                1
# ..               ...                 ...                ...              ...
# 366                1                   0                  0                0
# 398                0                   1                  0                1
# 16                 1                   0                 -1                0
# 393                0                   0                  0                0
# 131                0                   0                  0                0
#
#      pkt_3_ipv4_id_3  pkt_0_udp_len_12  pkt_0_ipv4_tl_15  pkt_1_ipv4_cksum_10  \
# 417                1                 1                 1                    1
# 75                 1                 1                 1                    0
# 176                0                 0                 0                    1
# 30                 1                 1                 0                    0
# 357                0                 1                 0                    0
# ..               ...               ...               ...                  ...
# 366                0                 0                 0                    1
# 398                0                 0                 0                    0
# 16                 0                -1                 0                    1
# 393                1                 1                 0                    1
# 131                0                 1                 0                    0
#
#      pkt_3_udp_len_15  pkt_0_udp_len_15
# 417                 1                 1
# 75                  1                 1
# 176                 1                 0
# 30                  1                 0
# 357                 0                 0
# ..                ...               ...
# 366                 0                 0
# 398                 0                 0
# 16                 -1                -1
# 393                 0                 0
# 131                -1                 0
#
# [107 rows x 37 columns]
#      label
# 304      1
# 3        1
# 18       1
# 325      2
# 60       1
# ..     ...
# 71       1
# 106      0
# 270      1
# 348      0
# 102      1
#
# [318 rows x 1 columns]
#      label
# 417      1
# 75       2
# 176      0
# 30       0
# 357      2
# ..     ...
# 366      1
# 398      2
# 16       2
# 393      1
# 131      0
#
# [107 rows x 1 columns]

# %%
# df_train.drop('pcap', axis=1, inplace=True)
# df_test.drop('pcap', axis=1, inplace=True)
label_train.drop('pcap', axis=1, inplace=True)
label_test.drop('pcap', axis=1, inplace=True)
label_train.rename(columns={'0': 'label'}, inplace=True)
label_test.rename(columns={'0': 'label'}, inplace=True)

# %%
#select a sub-dataframe with only the 40 top attrs rate by the AUTOGLUON feature importance algorithm
df_train = df_train[["pkt_1_ipv4_id_12","pkt_3_ipv4_tl_5","pkt_1_ipv4_ttl_4","pkt_2_ipv4_cksum_15","pkt_3_ipv4_dfbit_0","pkt_0_udp_cksum_2","pkt_3_ipv4_cksum_14","pkt_2_ipv4_ttl_6","pkt_1_udp_cksum_12","pkt_4_ipv4_cksum_13","pkt_3_ipv4_id_15","pkt_0_udp_sport_11","pkt_0_ipv4_ttl_1","pkt_1_ipv4_ttl_3","pkt_4_ipv4_id_13","pkt_0_ipv4_id_2","pkt_1_udp_len_15","pkt_1_udp_cksum_2","pkt_2_ipv4_ttl_3","pkt_3_udp_cksum_11","pkt_4_ipv4_cksum_7","pkt_2_ipv4_cksum_3","pkt_0_udp_cksum_5","pkt_0_ipv4_cksum_0","pkt_0_ipv4_tos_6","pkt_1_ipv4_cksum_4","pkt_3_ipv4_id_8","pkt_4_ipv4_id_3","pkt_2_ipv4_cksum_9","pkt_1_udp_sport_2","pkt_1_ipv4_id_2","pkt_3_ipv4_id_3","pkt_0_udp_len_12","pkt_0_ipv4_tl_15","pkt_1_ipv4_cksum_10","pkt_3_udp_len_15","pkt_0_udp_len_15"]]
df_test = df_test[["pkt_1_ipv4_id_12","pkt_3_ipv4_tl_5","pkt_1_ipv4_ttl_4","pkt_2_ipv4_cksum_15","pkt_3_ipv4_dfbit_0","pkt_0_udp_cksum_2","pkt_3_ipv4_cksum_14","pkt_2_ipv4_ttl_6","pkt_1_udp_cksum_12","pkt_4_ipv4_cksum_13","pkt_3_ipv4_id_15","pkt_0_udp_sport_11","pkt_0_ipv4_ttl_1","pkt_1_ipv4_ttl_3","pkt_4_ipv4_id_13","pkt_0_ipv4_id_2","pkt_1_udp_len_15","pkt_1_udp_cksum_2","pkt_2_ipv4_ttl_3","pkt_3_udp_cksum_11","pkt_4_ipv4_cksum_7","pkt_2_ipv4_cksum_3","pkt_0_udp_cksum_5","pkt_0_ipv4_cksum_0","pkt_0_ipv4_tos_6","pkt_1_ipv4_cksum_4","pkt_3_ipv4_id_8","pkt_4_ipv4_id_3","pkt_2_ipv4_cksum_9","pkt_1_udp_sport_2","pkt_1_ipv4_id_2","pkt_3_ipv4_id_3","pkt_0_udp_len_12","pkt_0_ipv4_tl_15","pkt_1_ipv4_cksum_10","pkt_3_udp_len_15","pkt_0_udp_len_15"]]

#select a sub-dataframe with only the 27 top attrs rate by the AUTOGLUON feature importance algorithm
# df_train = df_train[["pkt_1_ipv4_tl_5","pkt_1_udp_len_9","pkt_0_udp_len_12","pkt_2_ipv4_tl_6","pkt_4_udp_len_8","pkt_3_udp_len_7","pkt_2_ipv4_tl_7","pkt_1_udp_len_8","pkt_3_ipv4_tl_5","pkt_0_udp_len_15","pkt_3_udp_len_15","pkt_1_udp_len_10","pkt_3_udp_len_9","pkt_0_ipv4_tl_10","pkt_2_udp_len_11","pkt_2_ipv4_tl_10","pkt_4_udp_len_7","pkt_1_udp_len_13","pkt_0_ipv4_tl_12","pkt_1_ipv4_tl_9","pkt_0_ipv4_ttl_6","pkt_3_ipv4_tl_11","pkt_2_ipv4_ttl_2","pkt_4_udp_dport_0","pkt_0_ipv4_ttl_2","pkt_1_udp_dport_1","pkt_2_udp_len_12"]]
# df_test = df_test[["pkt_1_ipv4_tl_5","pkt_1_udp_len_9","pkt_0_udp_len_12","pkt_2_ipv4_tl_6","pkt_4_udp_len_8","pkt_3_udp_len_7","pkt_2_ipv4_tl_7","pkt_1_udp_len_8","pkt_3_ipv4_tl_5","pkt_0_udp_len_15","pkt_3_udp_len_15","pkt_1_udp_len_10","pkt_3_udp_len_9","pkt_0_ipv4_tl_10","pkt_2_udp_len_11","pkt_2_ipv4_tl_10","pkt_4_udp_len_7","pkt_1_udp_len_13","pkt_0_ipv4_tl_12","pkt_1_ipv4_tl_9","pkt_0_ipv4_ttl_6","pkt_3_ipv4_tl_11","pkt_2_ipv4_ttl_2","pkt_4_udp_dport_0","pkt_0_ipv4_ttl_2","pkt_1_udp_dport_1","pkt_2_udp_len_12"]]

#select a sub-dataframe with only the 10 top attrs rate by the AUTOGLUON feature importance algorithm
# df_train = df_train[["pkt_1_ipv4_tl_5","pkt_1_udp_len_9","pkt_0_udp_len_12","pkt_2_ipv4_tl_6","pkt_4_udp_len_8","pkt_3_udp_len_7","pkt_2_ipv4_tl_7","pkt_1_udp_len_8","pkt_3_ipv4_tl_5","pkt_0_udp_len_15"]]
# df_test = df_test[["pkt_1_ipv4_tl_5","pkt_1_udp_len_9","pkt_0_udp_len_12","pkt_2_ipv4_tl_6","pkt_4_udp_len_8","pkt_3_udp_len_7","pkt_2_ipv4_tl_7","pkt_1_udp_len_8","pkt_3_ipv4_tl_5","pkt_0_udp_len_15"]]

# select a sub-dataframe with only the 5 top attrs rate by JV feature importance algorithm
# df_train = df_train[['pkt_1_udp_len_11','pkt_1_udp_len_9','pkt_1_ipv4_tl_9','pkt_1_ipv4_tl_11','pkt_0_udp_len_7']]
# df_test = df_test[['pkt_1_udp_len_11','pkt_1_udp_len_9','pkt_1_ipv4_tl_9','pkt_1_ipv4_tl_11','pkt_0_udp_len_7']]

# %% [markdown]
# ### NN training
#  model weights file generation
#
#  model parameters json file generation

# %%
# Begin NN training
NUMBER_OF_ATTRS = df_train.shape[1]

# Convert int values to TF expect values (float)
df_train = np.asarray(df_train).astype(np.float32)
df_test = np.asarray(df_test).astype(np.float32)
# Converts pandas dataframe to tensorflow object
df_train = tf.convert_to_tensor(df_train)
# Normalize the data
normalizer = tf.keras.layers.Normalization(axis=-1)
normalizer.adapt(df_train)
#normalizer.adapt(numeric_features_test)

# Execute Trainning and Testing
print('Starting training for',number_of_attributes,'attributes')
model = get_basic_model()
model.fit(df_train, label_train, epochs=EPOCHS, verbose=1, batch_size=BATCH_SIZE)

test_loss, one_test_acc =  model.evaluate(df_test,  label_test, verbose=1, batch_size=1)
tf_predictions_probabilities = model.predict(df_test)
tf_predictions = []

for i,x in enumerate(tf_predictions_probabilities):
  #print("i:",i,"x_max:",x.max(),"x:",x)
  j_max = x.argmax()
  tf_predictions.append(j_max)

conf_m = tf.math.confusion_matrix(label_test,tf_predictions)
print(conf_m)
# Out:
# Starting training for 16 attributes
# Epoch 1/10
# 32/32 [==============================] - 0s 1ms/step - loss: 1.3360 - accuracy: 0.3711
# Epoch 2/10
# 32/32 [==============================] - 0s 1ms/step - loss: 1.1315 - accuracy: 0.4686
# Epoch 3/10
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0282 - accuracy: 0.5283
# Epoch 4/10
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9588 - accuracy: 0.5629
# Epoch 5/10
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9038 - accuracy: 0.5912
# Epoch 6/10
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8594 - accuracy: 0.6006
# Epoch 7/10
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8236 - accuracy: 0.6164
# Epoch 8/10
# 32/32 [==============================] - 0s 1ms/step - loss: 0.7931 - accuracy: 0.6415
# Epoch 9/10
# 32/32 [==============================] - 0s 1ms/step - loss: 0.7638 - accuracy: 0.6509
# Epoch 10/10
# 32/32 [==============================] - 0s 1ms/step - loss: 0.7377 - accuracy: 0.6761
# 107/107 [==============================] - 0s 1ms/step - loss: 0.9970 - accuracy: 0.4953
# 4/4 [==============================] - 0s 3ms/step
# tf.Tensor(
# [[18  5  7]
#  [14 11 10]
#  [ 9  9 24]], shape=(3, 3), dtype=int32)

# %%
# Date for report file
now = datetime.now()
dt_string = now.strftime("%d-%m-%Y %H:%M:%S")
# Report file content
report = {
    "datetime": dt_string,
    "number_of_attributes": number_of_attributes,
    "hidden_layer_nodes": hidden_layer_nodes,
    "output_layer_nodes": output_layer_nodes,
    "accuracy_test": one_test_acc,
    "batch_size": BATCH_SIZE,
    "epochs": EPOCHS
    #"number_of_samples": number_of_samples,
    #"df_number": df_number
}


# norm_layer_weights = model.layers[0].get_weights()[0] #weight
# norm_layer_biases  = model.layers[0].get_weights()[1] #bias
# hidden_layer_weights = model.layers[1].get_weights()[0] #weight
# hidden_layer_biases  = model.layers[1].get_weights()[1] #bias
# out_layer_weights = model.layers[2].get_weights()[0] #weight
# out_layer_biases  = model.layers[2].get_weights()[1] #bias
# print('\nInput -> Normalization Layer bias:\n',norm_layer_biases)
# print('\nInput -> Normalization Layer weights:\n',norm_layer_weights)
# print('\nNormalization -> Hidden Layer bias:\n',hidden_layer_biases)
# print('\nNormalization -> Hidden Layer weights:\n',hidden_layer_weights)
# print('\nHidden -> Output Layer bias:\n',out_layer_biases)
# print('\nHidden -> Output Layer weights:\n',out_layer_weights,'\n')

# %%
# Writes into the file
# model parameters json file generation
title = f"/content/drive/MyDrive/network-traffic-classification-main/nn-reports/nn_nprint_country_origin_model_parameters_{number_of_attributes}x{hidden_layer_nodes}x{output_layer_nodes}_{dt_string}.json"
with open(title, "w") as f:
  json.dump(report, f)

title_parameters_save = f"/content/drive/MyDrive/network-traffic-classification-main/nn-reports/nn_nprint_country_origin_model_parameters_{number_of_attributes}x{hidden_layer_nodes}x{output_layer_nodes}.json"
with open(title_parameters_save, "w") as f:
  json.dump(report, f)

# Calling `save('my_model')` creates a SavedModel folder `my_model`.
# model weights file generation
title_model_save = f'/content/drive/MyDrive/network-traffic-classification-main/tf-models/nn_nprint_country_origin_trained_model_weights_{number_of_attributes}x{hidden_layer_nodes}x{output_layer_nodes}_{dt_string}.csv'
model.save(title_model_save)

title_model_save = f'/content/drive/MyDrive/network-traffic-classification-main/tf-models/nn_nprint_country_origin_trained_model_weights_{number_of_attributes}x{hidden_layer_nodes}x{output_layer_nodes}.csv'
model.save(title_model_save)
