# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# %%
accuracies = []
for i in range(34):
  title =  "/content/drive/MyDrive/network-traffic-classification-main/nn-reports/df1_2022-08-26 With %d"%(i+2) + " Attributes.json"
  with open(title, "r") as f:
    rep = json.load(f)
  accuracies.append(rep["accuracy_test"])

print(accuracies)
max_acc = max(accuracies)
min_acc = min(accuracies)
len_acc = len(accuracies)
# Out:
# [0.6647916436195374, 0.6643750071525574, 0.6952083110809326, 0.7292291522026062, 0.7068958282470703, 0.7435625195503235, 0.7528541684150696, 0.7667708396911621, 0.7652291655540466, 0.7644166648387909, 0.7755833268165588, 0.7830625176429749, 0.7742291688919067, 0.781416654586792, 0.7827916741371155, 0.7899791598320007, 0.7879374921321869, 0.7793124914169312, 0.789041668176651, 0.7854374945163727, 0.7813958525657654, 0.7873958349227905, 0.7756041586399078, 0.7833749949932098, 0.7886458337306976, 0.7797083258628845, 0.7956041693687439, 0.796770840883255, 0.7930833399295807, 0.7922291457653046, 0.7942083179950714, 0.7815833389759064, 0.7998541593551636, 0.7908124923706055]

# %%
xc = range(2,len_acc+2)
plt.figure(figsize=[8, 6])
plt.plot(xc, accuracies)
plt.ylabel('Acurácia de teste')
plt.xlabel('Número de atributos')
plt.title('Acurácia de teste por número de atributos')

y=np.arange(0.6,0.8,0.01)
z=np.arange(min_acc,max_acc,0.005)

plt.xticks(range(len(accuracies)+2))
plt.yticks(y)
plt.ylim(min_acc-0.0025, max_acc+0.0025)
for i in y:
  plt.axhline(i, color="black", linestyle=":")
for i in range(0,len_acc+2,2):
  plt.axvline(i, color="black", linestyle=":")

# Date for report file
now = datetime.now()
dt_string = now.strftime("%d-%m-%Y %H:%M:%S")
title = "/content/drive/MyDrive/network-traffic-classification-main/nn-reports/KneeCurve_%s"%dt_string + ".pdf"
plt.savefig(title)
