# %%
# Load R
# %reload_ext rpy2.ipython
# %config IPCompleter.greedy=True
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# After that, every time you want to use R, add %%R in the beginning of each cell.

# %%
# !pip uninstall rpy2 -y
# Out:
# Found existing installation: rpy2 3.5.5
# Uninstalling rpy2-3.5.5:
#   Successfully uninstalled rpy2-3.5.5

# %%
# !pip install rpy2==3.5.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 201 kB 6.3 MB/s
# ...
#   Created wheel for rpy2: filename=rpy2-3.5.1-cp38-cp38-linux_x86_64.whl size=310199 sha256=fcc86b6513baedb1d68bb3b39da4a3f59cd0409c680c2349f961089fee68fefc
#   Stored in directory: /root/.cache/pip/wheels/6b/40/7d/f63e87fd83e8b99ee837c8e3489081c4b3489134bc520235ed
# Successfully built rpy2
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv(f"/content/drive/MyDrive/Tutorial R/numeros.csv")

# %%
# %%R
# data <- read.csv("/content/drive/MyDrive/Tutorial R/numeros.csv")
# print(data)
# Out:
#   id     name salary start_date       dept
# 1  1     Rick 623.30 2012-01-01         IT
# 2  2      Dan 515.20 2013-09-23 Operations
# 3  3 Michelle 611.00 2014-11-15         IT
# 4  4     Ryan 729.00 2014-05-11         HR
# 5  5     Gary 843.25 2015-03-27    Finance
# 6  6     Nina 578.00 2013-05-21         IT
# 7  7    Simon 632.80 2013-07-30 Operations
# 8  8     Guru 722.50 2014-06-17    Finance

# %%
# %%R
# sal <- max(data$salary)
# media_sal = mean(data$salary)
# cat("maior salario: ", sal)
# cat("média salarial salario: ", media_sal)
# Out:
# maior salario:  843.25média salarial salario:  656.8813
