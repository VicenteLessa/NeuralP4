# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import matplotlib.pyplot as plt

# %%
accuracies = []
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-19 With 2 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-19 With 3 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-19 With 4 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-19 With 5 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-19 With 6 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-19 With 7 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-19 With 8 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-19 With 9 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-19 With 10 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-19 With 11 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-19 With 12 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-19 With 13 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-19 With 14 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-19 With 15 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-19 With 16 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-19 With 17 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-19 With 18 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-19 With 19 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-19 With 20 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-19 With 21 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-01-19 With 22 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])

print(accuracies)

xc = range(2,23)
plt.figure()
plt.plot(xc, accuracies)
plt.ylabel('Test Accuracy')
plt.xlabel('Number of Attributes')
plt.title('Test Accuracy by Number of Attributes')
plt.xticks(range(23))

print()
# Out:
# [0.8831561803817749, 0.9173564314842224, 0.9173144102096558, 0.9167261719703674, 0.9163060188293457, 0.9342464804649353, 0.9329439997673035, 0.9529851675033569, 0.9507583975791931, 0.9505062699317932, 0.9467249512672424, 0.95130455493927, 0.9555901288986206, 0.9591193795204163, 0.951808750629425, 0.9587832689285278, 0.9558001756668091, 0.9369774460792542, 0.9498340487480164, 0.9579009413719177, 0.9557581543922424]
