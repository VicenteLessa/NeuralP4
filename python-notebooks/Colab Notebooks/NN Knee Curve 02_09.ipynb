# %%
from google.colab import drive
drive.mount('/content/drive')
from datetime import datetime
import json
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Mounted at /content/drive

# %%
# accuracies = []
# accuracies2 = []
# accuracies3 = []
# accuracies4 = []
# accuracies5 = []

# accuracies6 = []
# accuracies7 = []
# accuracies8 = []

accuracies9 = []
accuracies10 = []
accuracies11 = []

# accuracies_train4 = []
# accuracies_train5 = []

# accuracies_train6 = []
# accuracies_train7 = []
# accuracies_train8 = []

accuracies_train9 = []
accuracies_train10 = []
accuracies_train11 = []


# for i in range(34):
#   title =  "/content/drive/MyDrive/network-traffic-classification-main/nn-reports/df0_2022-09-01_with_%d"%(i+2) + "_attributes.json"
#   with open(title, "r") as f:
#     rep = json.load(f)
#   accuracies.append(rep["accuracy_test"])
  
# for i in range(34):
#   title =  "/content/drive/MyDrive/network-traffic-classification-main/nn-reports/df1_2022-09-01_with_%d"%(i+2) + "_attributes.json"
#   with open(title, "r") as f:
#     rep = json.load(f)
#   accuracies2.append(rep["accuracy_test"])
  
# for i in range(34):
#   title =  "/content/drive/MyDrive/network-traffic-classification-main/nn-reports/df3_2022-09-01_with_%d"%(i+2) + "_attributes.json"
#   with open(title, "r") as f:
#     rep = json.load(f)
#   accuracies3.append(rep["accuracy_test"])

# for i in range(34):
#   title =  "/content/drive/MyDrive/network-traffic-classification-main/nn-reports/df4_2022-09-02_with_%d"%(i+2) + "_attributes.json"
#   with open(title, "r") as f:
#     rep = json.load(f)
#   accuracies4.append(rep["accuracy_test"])
#   accuracies_train4.append(rep["accuracy_train"])  
  
# for i in range(34):
#   title =  "/content/drive/MyDrive/network-traffic-classification-main/nn-reports/df5_2022-09-02_with_%d"%(i+2) + "_attributes.json"
#   with open(title, "r") as f:
#     rep = json.load(f)
#   accuracies5.append(rep["accuracy_test"])
#   accuracies_train5.append(rep["accuracy_train"])

# for i in range(34):
#   title =  "/content/drive/MyDrive/network-traffic-classification-main/nn-reports/df1_2022-09-05_with_%d"%(i+2) + "_attributes.json"
#   with open(title, "r") as f:
#     rep = json.load(f)
#   accuracies6.append(rep["accuracy_test"])
#   accuracies_train6.append(rep["accuracy_train"])

# for i in range(34):
#   title =  "/content/drive/MyDrive/network-traffic-classification-main/nn-reports/df2_2022-09-05_with_%d"%(i+2) + "_attributes.json"
#   with open(title, "r") as f:
#     rep = json.load(f)
#   accuracies7.append(rep["accuracy_test"])
#   accuracies_train7.append(rep["accuracy_train"])

# for i in range(34):
#   title =  "/content/drive/MyDrive/network-traffic-classification-main/nn-reports/df3_2022-09-05_with_%d"%(i+2) + "_attributes.json"
#   with open(title, "r") as f:
#     rep = json.load(f)
#   accuracies8.append(rep["accuracy_test"])
#   accuracies_train8.append(rep["accuracy_train"])

# %%
for i in range(34):
  title =  f"/content/drive/MyDrive/network-traffic-classification-main/nn-reports/df1_2022-09-16_with_{i+2}_attributes.json"
  with open(title, "r") as f:
    rep = json.load(f)
  accuracies9.append(rep["accuracy_test"])
  accuracies_train9.append(rep["accuracy_train"])

for i in range(34):
  title =  f"/content/drive/MyDrive/network-traffic-classification-main/nn-reports/df2_2022-09-16_with_{i+2}_attributes.json"
  with open(title, "r") as f:
    rep = json.load(f)
  accuracies10.append(rep["accuracy_test"])
  accuracies_train10.append(rep["accuracy_train"])

for i in range(19):
  title =  f"/content/drive/MyDrive/network-traffic-classification-main/nn-reports/df3_2022-09-16_with_{i+2}_attributes.json"
  with open(title, "r") as f:
    rep = json.load(f)
  accuracies11.append(rep["accuracy_test"])
  accuracies_train11.append(rep["accuracy_train"])

for i in range(15):
  title =  f"/content/drive/MyDrive/network-traffic-classification-main/nn-reports/df3_2022-09-17_with_{19+2}_attributes.json"
  with open(title, "r") as f:
    rep = json.load(f)
  accuracies11.append(rep["accuracy_test"])
  accuracies_train11.append(rep["accuracy_train"])

# %%
# multiple_lists = [accuracies, accuracies2, accuracies3, accuracies4, accuracies5]
# arrays = [np.array(x) for x in multiple_lists]
# accuracies_2000samples = [np.mean(k) for k in zip(*arrays)]

# multiple_lists = [accuracies6, accuracies7, accuracies8]
# arrays = [np.array(x) for x in multiple_lists]
# accuracies_10000samples = [np.mean(k) for k in zip(*arrays)]

# multiple_lists = [accuracies_train4, accuracies_train5]
# arrays = [np.array(x) for x in multiple_lists]
# accuracies_train_2000samples = [np.mean(k) for k in zip(*arrays)]

# multiple_lists = [accuracies_train6, accuracies_train7, accuracies_train8]
# arrays = [np.array(x) for x in multiple_lists]
# accuracies_train_10000samples = [np.mean(k) for k in zip(*arrays)]

multiple_lists = [accuracies9, accuracies10, accuracies11]
arrays = [np.array(x) for x in multiple_lists]
accuracies_2000_test = [np.mean(k) for k in zip(*arrays)]
accuracies_2000_test = list(map(lambda item: item * 100, accuracies_2000_test))

multiple_lists = [accuracies_train9, accuracies_train10, accuracies_train11]
arrays = [np.array(x) for x in multiple_lists]
accuracies_8000_train = [np.mean(k) for k in zip(*arrays)]
accuracies_8000_train = list(map(lambda item: item * 100, accuracies_8000_train))

# %%
print(accuracies_8000_train)
# Out:
# [72.98969957563611, 79.45451339085898, 80.83495299021402, 81.05821675724454, 81.15428421232437, 84.0773151980506, 86.44780053032768, 86.6060197353363, 86.86562511656018, 87.24004626274109, 88.17256887753805, 88.62569464577568, 88.88344830936855, 89.4781251748403, 89.46342600716486, 89.17673627535501, 89.25844894515143, 89.71053229437933, 89.52893416086832, 89.46411940786572, 89.39386672443814, 89.46932885381912, 89.59143492910599, 89.79085617595248, 89.85150456428528, 89.4538184007009, 89.80092538727654, 89.59282437960306, 89.58217634095085, 89.57962857352362, 89.84907401932611, 89.76388772328696, 89.64479102028741, 89.88865746392143]

# %%
max_acc = max(accuracies_8000_train) 
min_acc = min(accuracies_2000_test)
len_acc = len(accuracies_2000_test)

xc = range(2,len_acc+2)
plt.figure(figsize=[8, 6])


# plt.plot(xc, accuracies_2000samples , color='green')
# plt.plot(xc, accuracies_train_2000samples, color='lime')

# plt.plot(xc, accuracies_train_10000samples, color='magenta')
# plt.plot(xc, accuracies_10000samples, color='purple')


plt.plot(xc, accuracies_8000_train, color='green', label="Treino")
plt.plot(xc, accuracies_2000_test, color='blue', label="Teste")

plt.ylabel('Acurácias de treino e teste (%)')
plt.xlabel('Número de atributos')
#plt.title('Acurácias de treino e teste por número de atributos')
plt.legend()

y=np.arange(5,95,2.5)
# z=np.arange(min_acc,max_acc,0.0025)

plt.xticks(range(0,34+2,2))
plt.yticks(y)
plt.ylim(min_acc-1, max_acc+1)
for i in y:
  plt.axhline(i, color="grey", linestyle=":")
for i in range(0,len_acc+2,2):
  plt.axvline(i, color="grey", linestyle=":")

# Date for report file
now = datetime.now()
dt_string = now.strftime("%d-%m-%Y %H:%M:%S")
title = "/content/drive/MyDrive/network-traffic-classification-main/nn-reports/KneeCurve_%s"%dt_string + ".pdf"
plt.savefig(title)

# %% [markdown]
# 8000 amostras de treino, 2000 de teste
# Amarelo: Acurácias de Treino
# Laranja: Acurácia de teste
#
# 2000 amostras de treino e teste
# Verde claro: treino
# Verde escuro: teste
#
# 10000 amostras de treino e teste
# rosa: treino
# roxo: teste
