# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import matplotlib.pyplot as plt
import numpy as np

# %%
accuracies = []
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-02 With 2 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-02 With 3 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-02 With 4 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-02 With 5 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-02 With 6 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-02 With 7 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-02 With 8 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-02 With 9 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-02 With 10 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-02 With 11 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-02 With 12 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-02 With 13 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-02 With 14 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-02 With 15 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-02 With 16 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-02 With 17 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-02 With 18 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-02 With 19 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])
with open("/content/drive/MyDrive/IC-Skynet/NNreports/2022-02-02 With 20 Attributes.json", "r") as f:
  rep = json.load(f)
accuracies.append(rep["accuracy_test"])


print(accuracies)

max_acc = max(accuracies)
min_acc = min(accuracies)
len_acc = len(accuracies)

xc = range(2,len_acc+2)
plt.figure()
plt.plot(xc, accuracies)
plt.ylabel('Test Accuracy')
plt.xlabel('Number of Attributes')
plt.title('Test Accuracy by Number of Attributes using Permutation Shuffing')

y=np.arange(0.9,0.99,0.005)
z=np.arange(min_acc,max_acc,0.005)

plt.xticks(range(len(accuracies)+2))
plt.yticks(y)
plt.ylim(min_acc-0.0025, max_acc+0.0025)
for i in y:
  plt.axhline(i, color="black", linestyle=":")
for i in range(0,len_acc+2,2):
  plt.axvline(i, color="black", linestyle=":")

plt.savefig('/content/drive/MyDrive/IC-Skynet/NNreports/IC NN Permutations0202')



print()
# Out:
# [0.9283223152160645, 0.9224822521209717, 0.9450443387031555, 0.9392462372779846, 0.9428175091743469, 0.9421873092651367, 0.9523969292640686, 0.9493298530578613, 0.9510945081710815, 0.9529011249542236, 0.955548107624054, 0.9568925499916077, 0.9594554901123047, 0.9525229930877686, 0.9556741118431091, 0.969581127166748, 0.9681105613708496, 0.9582790732383728, 0.9540775418281555]
